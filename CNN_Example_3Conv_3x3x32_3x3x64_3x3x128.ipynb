# %%
# colab 에서 tensorflow 1.x 실행
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime      # datetime.now() 를 이용하여 학습 경과 시간 측정

# read_data_sets() 를 통해 데이터를 객체형태로 받아오고
# one_hot 옵션을 통해 정답(label) 을 one-hot 인코딩된 형태로 받아옴

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# mnist 데이터 셋은 train, test, validation 3개의 데이터 셋으로 구성되어 있으며.
# num_examples 값을 통해 데이터의 갯수 확인 가능함

print("\n", mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

# 데이터는 784(28x28)개의 픽셀을 가지는 이미지와
# 10(0~9)개 클래스를 가지는 one-hot 인코딩된 레이블(정답)을 가지고 있음

print("\ntrain image shape = ", np.shape(mnist.train.images))
print("train label shape = ", np.shape(mnist.train.labels))
print("test image shape = ", np.shape(mnist.test.images))
print("test label shape = ", np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-2-37edfc5623ff>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
# Hyper-Parameter
learning_rate = 0.001  # 학습율
epochs = 50            # 반복횟수
batch_size = 100      # 한번에 입력으로 주어지는 MNIST 개수

# %%
# 입력과 정답을 위한 플레이스홀더 정의
X = tf.placeholder(tf.float32, [None, 784])  

T = tf.placeholder(tf.float32, [None, 10])  

# 입력층의 출력 값. 컨볼루션 연산을 위해 reshape 시킴
A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])   # image 28 X 28 X 1 (black/white)

# %%
# 1번째 컨볼루션 층
# 3X3 크기를 가지는 32개의 필터를 적용

F2 = tf.Variable(tf.random_normal([3, 3, 1, 32], stddev=0.01))  
#b2 = tf.Variable(tf.random_normal([32]))   
b2 = tf.Variable(tf.constant(0.1, shape=[32]))  

# 1번째 컨볼루션 연산을 통해 28 X 28 X1  => 28 X 28 X 32 
C2 = tf.nn.conv2d(A1, F2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 32  => 14 X 14 X 32 
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 2번째 컨볼루션 층
F3 = tf.Variable(tf.random_normal([3, 3, 32, 64], stddev=0.01))  
#b3 = tf.Variable(tf.random_normal([64]))   
b3 = tf.Variable(tf.constant(0.1, shape=[64]))  

# 2번째 컨볼루션 연산을 통해 14 X 14 X 32 => 14 X 14 X 64 
C3 = tf.nn.conv2d(A2, F3, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z3 = tf.nn.relu(C3+b3)

# 2번째 max pooling을 통해 14 X 14 X 64 => 7 X 7 X 64
A3 = P3 = tf.nn.max_pool(Z3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 3번째 컨볼루션 층
F4 = tf.Variable(tf.random_normal([3, 3, 64, 128], stddev=0.01))  
#b4 = tf.Variable(tf.random_normal([128]))   
b4 = tf.Variable(tf.constant(0.1, shape=[128]))  

# 3번째 컨볼루션 연산을 통해 7 X 7 X 64 => 7 X 7 X 128
C4 = tf.nn.conv2d(A3, F4, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z4 = tf.nn.relu(C4+b4)

# 3번째 max pooling을 통해 7 X 7 X 128 => 4 X 4 X 128
A4 = P4 = tf.nn.max_pool(Z4, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 4X4 크기를 가진 128개의 activation map을 flatten 시킴
A4_flat = P4_flat = tf.reshape(A4, [-1, 128*4*4])

# %%
# 출력층
W5 = tf.Variable(tf.random_normal([128*4*4, 10], stddev=0.01))
b5 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z5, 즉 softmax 에 들어가는 입력 값
Z5 = logits = tf.matmul(A4_flat, W5) + b5    # 선형회귀 값 Z5

y = A5 = tf.nn.softmax(Z5)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z5, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A5, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# index list 출력
accuracy_index = tf.cast(predicted_val, dtype=tf.float32)

# 예측값 처리
predicted_list = tf.argmax(A5, 1)

# %%
index_label_prediction_list = []

with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    # 30 번 반복수행
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val = sess.run([accuracy], feed_dict={X: test_x_data, T: test_t_data})
# Out:
# epochs =  0 , step =  0 , loss_val =  2.7331676
# epochs =  0 , step =  100 , loss_val =  1.7306676
# epochs =  0 , step =  200 , loss_val =  0.35471573
# epochs =  0 , step =  300 , loss_val =  0.2106719
# epochs =  0 , step =  400 , loss_val =  0.10681215
# epochs =  0 , step =  500 , loss_val =  0.020440197
# epochs =  1 , step =  0 , loss_val =  0.06276152
# epochs =  1 , step =  100 , loss_val =  0.035776757
# epochs =  1 , step =  200 , loss_val =  0.057375416
# epochs =  1 , step =  300 , loss_val =  0.12569164
# epochs =  1 , step =  400 , loss_val =  0.01692431
# epochs =  1 , step =  500 , loss_val =  0.040316906
# epochs =  2 , step =  0 , loss_val =  0.03216313
# epochs =  2 , step =  100 , loss_val =  0.07538155
# epochs =  2 , step =  200 , loss_val =  0.031711895
# epochs =  2 , step =  300 , loss_val =  0.035866477
# epochs =  2 , step =  400 , loss_val =  0.03772566
# epochs =  2 , step =  500 , loss_val =  0.07590705
# epochs =  3 , step =  0 , loss_val =  0.02327886
# epochs =  3 , step =  100 , loss_val =  0.05617876
# epochs =  3 , step =  200 , loss_val =  0.014681242
# epochs =  3 , step =  300 , loss_val =  0.0027127725
# epochs =  3 , step =  400 , loss_val =  0.005483015
# epochs =  3 , step =  500 , loss_val =  0.07293605
# epochs =  4 , step =  0 , loss_val =  0.06519287
# epochs =  4 , step =  100 , loss_val =  0.03995925
# epochs =  4 , step =  200 , loss_val =  0.014565807
# epochs =  4 , step =  300 , loss_val =  0.023050623
# epochs =  4 , step =  400 , loss_val =  0.0023007323
# epochs =  4 , step =  500 , loss_val =  0.054491334
# epochs =  5 , step =  0 , loss_val =  0.018565867
# epochs =  5 , step =  100 , loss_val =  0.022262199
# epochs =  5 , step =  200 , loss_val =  0.015159476
# epochs =  5 , step =  300 , loss_val =  0.041510247
# epochs =  5 , step =  400 , loss_val =  0.012570698
# epochs =  5 , step =  500 , loss_val =  0.004140597
# epochs =  6 , step =  0 , loss_val =  0.022091737
# epochs =  6 , step =  100 , loss_val =  0.0060580536
# epochs =  6 , step =  200 , loss_val =  0.04010878
# epochs =  6 , step =  300 , loss_val =  0.09928115
# epochs =  6 , step =  400 , loss_val =  0.0061355066
# epochs =  6 , step =  500 , loss_val =  0.0053399783
# epochs =  7 , step =  0 , loss_val =  0.021764316
# epochs =  7 , step =  100 , loss_val =  0.000735203
# epochs =  7 , step =  200 , loss_val =  0.011389907
# epochs =  7 , step =  300 , loss_val =  0.022573505
# epochs =  7 , step =  400 , loss_val =  0.010907532
# epochs =  7 , step =  500 , loss_val =  0.00086254155
# epochs =  8 , step =  0 , loss_val =  0.0009613116
# epochs =  8 , step =  100 , loss_val =  0.00389924
# epochs =  8 , step =  200 , loss_val =  0.0020464603
# epochs =  8 , step =  300 , loss_val =  0.0034472588
# epochs =  8 , step =  400 , loss_val =  0.004099896
# epochs =  8 , step =  500 , loss_val =  0.0016817832
# epochs =  9 , step =  0 , loss_val =  0.0053653843
# epochs =  9 , step =  100 , loss_val =  0.0007618285
# epochs =  9 , step =  200 , loss_val =  0.005622617
# epochs =  9 , step =  300 , loss_val =  0.009657142
# epochs =  9 , step =  400 , loss_val =  0.009203438
# epochs =  9 , step =  500 , loss_val =  0.0015928395
# epochs =  10 , step =  0 , loss_val =  0.066212445
# epochs =  10 , step =  100 , loss_val =  0.04907744
# epochs =  10 , step =  200 , loss_val =  0.09659933
# epochs =  10 , step =  300 , loss_val =  0.00081579125
# epochs =  10 , step =  400 , loss_val =  9.07398e-05
# epochs =  10 , step =  500 , loss_val =  0.00063598284
# epochs =  11 , step =  0 , loss_val =  0.0003454025
# epochs =  11 , step =  100 , loss_val =  0.0014603216
# epochs =  11 , step =  200 , loss_val =  0.0014623489
# epochs =  11 , step =  300 , loss_val =  0.0007238283
# epochs =  11 , step =  400 , loss_val =  0.0005243954
# epochs =  11 , step =  500 , loss_val =  0.00093897706
# epochs =  12 , step =  0 , loss_val =  0.0002726904
# epochs =  12 , step =  100 , loss_val =  0.006972877
# epochs =  12 , step =  200 , loss_val =  0.0032690468
# epochs =  12 , step =  300 , loss_val =  0.010608668
# epochs =  12 , step =  400 , loss_val =  0.00070378295
# epochs =  12 , step =  500 , loss_val =  0.0018319313
# epochs =  13 , step =  0 , loss_val =  0.00018080426
# epochs =  13 , step =  100 , loss_val =  0.002679196
# epochs =  13 , step =  200 , loss_val =  0.0011073309
# epochs =  13 , step =  300 , loss_val =  0.0022355276
# epochs =  13 , step =  400 , loss_val =  0.058813322
# epochs =  13 , step =  500 , loss_val =  0.0023324452
# epochs =  14 , step =  0 , loss_val =  0.00033359937
# epochs =  14 , step =  100 , loss_val =  0.0005196771
# epochs =  14 , step =  200 , loss_val =  0.0010422326
# epochs =  14 , step =  300 , loss_val =  0.00012296854
# epochs =  14 , step =  400 , loss_val =  0.0007178139
# epochs =  14 , step =  500 , loss_val =  0.00035986278
# epochs =  15 , step =  0 , loss_val =  4.84542e-05
# epochs =  15 , step =  100 , loss_val =  0.00032035404
# epochs =  15 , step =  200 , loss_val =  0.00042787357
# epochs =  15 , step =  300 , loss_val =  0.00074062357
# epochs =  15 , step =  400 , loss_val =  0.00033563256
# epochs =  15 , step =  500 , loss_val =  0.0041047307
# epochs =  16 , step =  0 , loss_val =  0.0005499737
# epochs =  16 , step =  100 , loss_val =  0.00093953765
# epochs =  16 , step =  200 , loss_val =  0.05217577
# epochs =  16 , step =  300 , loss_val =  7.14557e-05
# epochs =  16 , step =  400 , loss_val =  0.0025944607
# epochs =  16 , step =  500 , loss_val =  0.0010199192
# epochs =  17 , step =  0 , loss_val =  0.0020957645
# epochs =  17 , step =  100 , loss_val =  1.9240515e-05
# epochs =  17 , step =  200 , loss_val =  0.0010637967
# epochs =  17 , step =  300 , loss_val =  0.0025942167
# epochs =  17 , step =  400 , loss_val =  0.00082675164
# epochs =  17 , step =  500 , loss_val =  0.002560488
# epochs =  18 , step =  0 , loss_val =  0.00030388625
# epochs =  18 , step =  100 , loss_val =  0.01966263
# epochs =  18 , step =  200 , loss_val =  0.004012715
# epochs =  18 , step =  300 , loss_val =  0.010137061
# epochs =  18 , step =  400 , loss_val =  0.00047723047
# epochs =  18 , step =  500 , loss_val =  0.00048638805
# epochs =  19 , step =  0 , loss_val =  0.00018530757
# epochs =  19 , step =  100 , loss_val =  6.505299e-05
# epochs =  19 , step =  200 , loss_val =  0.011519194
# epochs =  19 , step =  300 , loss_val =  0.010096089
# epochs =  19 , step =  400 , loss_val =  0.0009581691
# epochs =  19 , step =  500 , loss_val =  3.1196036e-05
# epochs =  20 , step =  0 , loss_val =  9.962079e-05
# epochs =  20 , step =  100 , loss_val =  6.3368374e-05
# epochs =  20 , step =  200 , loss_val =  4.5766505e-05
# epochs =  20 , step =  300 , loss_val =  0.025382252
# epochs =  20 , step =  400 , loss_val =  0.00023578413
# epochs =  20 , step =  500 , loss_val =  0.038911916
# epochs =  21 , step =  0 , loss_val =  0.00781725
# epochs =  21 , step =  100 , loss_val =  2.8032042e-05
# epochs =  21 , step =  200 , loss_val =  0.00014873975
# epochs =  21 , step =  300 , loss_val =  0.0001474102
# epochs =  21 , step =  400 , loss_val =  1.7236096e-05
# epochs =  21 , step =  500 , loss_val =  8.5324245e-06
# epochs =  22 , step =  0 , loss_val =  0.00017730852
# epochs =  22 , step =  100 , loss_val =  0.0008627519
# epochs =  22 , step =  200 , loss_val =  8.773427e-05
# epochs =  22 , step =  300 , loss_val =  5.0647956e-05
# epochs =  22 , step =  400 , loss_val =  0.01810535
# epochs =  22 , step =  500 , loss_val =  0.026632251
# epochs =  23 , step =  0 , loss_val =  0.0009334273
# epochs =  23 , step =  100 , loss_val =  0.00044485836
# epochs =  23 , step =  200 , loss_val =  5.4466655e-05
# epochs =  23 , step =  300 , loss_val =  0.05795077
# epochs =  23 , step =  400 , loss_val =  0.0012037266
# epochs =  23 , step =  500 , loss_val =  0.0008777132
# epochs =  24 , step =  0 , loss_val =  0.00085660187
# epochs =  24 , step =  100 , loss_val =  0.0030426488
# epochs =  24 , step =  200 , loss_val =  0.00020940181
# epochs =  24 , step =  300 , loss_val =  4.5554134e-06
# epochs =  24 , step =  400 , loss_val =  0.00047045175
# epochs =  24 , step =  500 , loss_val =  4.2184336e-05
# epochs =  25 , step =  0 , loss_val =  5.0057093e-05
# epochs =  25 , step =  100 , loss_val =  0.0002495786
# epochs =  25 , step =  200 , loss_val =  0.00016358803
# epochs =  25 , step =  300 , loss_val =  0.00011272506
# epochs =  25 , step =  400 , loss_val =  3.543076e-05
# epochs =  25 , step =  500 , loss_val =  0.00020507738
# epochs =  26 , step =  0 , loss_val =  0.00082393276
# epochs =  26 , step =  100 , loss_val =  0.006218691
# epochs =  26 , step =  200 , loss_val =  4.8701586e-05
# epochs =  26 , step =  300 , loss_val =  0.0045211874
# epochs =  26 , step =  400 , loss_val =  0.0117345955
# epochs =  26 , step =  500 , loss_val =  0.021821627
# epochs =  27 , step =  0 , loss_val =  7.273389e-05
# epochs =  27 , step =  100 , loss_val =  0.00053047494
# epochs =  27 , step =  200 , loss_val =  0.0014522652
# epochs =  27 , step =  300 , loss_val =  0.0028853302
# epochs =  27 , step =  400 , loss_val =  3.0398138e-07
# epochs =  27 , step =  500 , loss_val =  3.19226e-06
# epochs =  28 , step =  0 , loss_val =  2.8608383e-05
# epochs =  28 , step =  100 , loss_val =  0.009853912
# epochs =  28 , step =  200 , loss_val =  0.0010098359
# epochs =  28 , step =  300 , loss_val =  4.50285e-05
# epochs =  28 , step =  400 , loss_val =  3.505363e-05
# epochs =  28 , step =  500 , loss_val =  0.00014362023
# epochs =  29 , step =  0 , loss_val =  0.00043494604
# epochs =  29 , step =  100 , loss_val =  0.00015095636
# epochs =  29 , step =  200 , loss_val =  1.16824864e-07
# epochs =  29 , step =  300 , loss_val =  0.0036794099
# epochs =  29 , step =  400 , loss_val =  0.011608479
# epochs =  29 , step =  500 , loss_val =  3.9086317e-05
# epochs =  30 , step =  0 , loss_val =  2.3803173e-05
# epochs =  30 , step =  100 , loss_val =  5.8857197e-05
# epochs =  30 , step =  200 , loss_val =  3.5877558e-05
# epochs =  30 , step =  300 , loss_val =  0.0037574705
# epochs =  30 , step =  400 , loss_val =  0.000771176
# epochs =  30 , step =  500 , loss_val =  0.00015403662
# epochs =  31 , step =  0 , loss_val =  0.00012773457
# epochs =  31 , step =  100 , loss_val =  1.6617916e-05
# epochs =  31 , step =  200 , loss_val =  8.8807747e-07
# epochs =  31 , step =  300 , loss_val =  3.7225407e-06
# epochs =  31 , step =  400 , loss_val =  0.00043074612
# epochs =  31 , step =  500 , loss_val =  1.4708195e-05
# epochs =  32 , step =  0 , loss_val =  4.3391353e-07
# epochs =  32 , step =  100 , loss_val =  0.0013614787
# epochs =  32 , step =  200 , loss_val =  0.00012004742
# epochs =  32 , step =  300 , loss_val =  1.18286835e-05
# epochs =  32 , step =  400 , loss_val =  0.00015477043
# epochs =  32 , step =  500 , loss_val =  0.00015085372
# epochs =  33 , step =  0 , loss_val =  0.017392166
# epochs =  33 , step =  100 , loss_val =  2.953154e-05
# epochs =  33 , step =  200 , loss_val =  0.00033375152
# epochs =  33 , step =  300 , loss_val =  4.4941598e-07
# epochs =  33 , step =  400 , loss_val =  2.262481e-06
# epochs =  33 , step =  500 , loss_val =  0.00017047623
# epochs =  34 , step =  0 , loss_val =  0.00015757054
# epochs =  34 , step =  100 , loss_val =  2.5805753e-06
# epochs =  34 , step =  200 , loss_val =  7.9314916e-05
# epochs =  34 , step =  300 , loss_val =  1.394747e-07
# epochs =  34 , step =  400 , loss_val =  7.760416e-07
# epochs =  34 , step =  500 , loss_val =  8.500863e-05
# epochs =  35 , step =  0 , loss_val =  1.2466319e-05
# epochs =  35 , step =  100 , loss_val =  0.0019265759
# epochs =  35 , step =  200 , loss_val =  0.00030495928
# epochs =  35 , step =  300 , loss_val =  2.8084596e-06
# epochs =  35 , step =  400 , loss_val =  0.026739016
# epochs =  35 , step =  500 , loss_val =  0.0013813187
# epochs =  36 , step =  0 , loss_val =  0.0019352937
# epochs =  36 , step =  100 , loss_val =  5.6056942e-06
# epochs =  36 , step =  200 , loss_val =  0.0045356667
# epochs =  36 , step =  300 , loss_val =  8.344648e-09
# epochs =  36 , step =  400 , loss_val =  5.567015e-07
# epochs =  36 , step =  500 , loss_val =  0.0011765818
# epochs =  37 , step =  0 , loss_val =  5.4685106e-06
# epochs =  37 , step =  100 , loss_val =  5.59068e-06
# epochs =  37 , step =  200 , loss_val =  0.000580627
# epochs =  37 , step =  300 , loss_val =  3.3555898e-05
# epochs =  37 , step =  400 , loss_val =  2.9802004e-07
# epochs =  37 , step =  500 , loss_val =  5.793513e-07
# epochs =  38 , step =  0 , loss_val =  3.7916031e-06
# epochs =  38 , step =  100 , loss_val =  2.867776e-05
# epochs =  38 , step =  200 , loss_val =  1.778591e-05
# epochs =  38 , step =  300 , loss_val =  9.834541e-07
# epochs =  38 , step =  400 , loss_val =  3.200574e-06
# epochs =  38 , step =  500 , loss_val =  6.2433623e-06
# epochs =  39 , step =  0 , loss_val =  0.0012064041
# epochs =  39 , step =  100 , loss_val =  1.6200087e-06
# epochs =  39 , step =  200 , loss_val =  5.203838e-06
# epochs =  39 , step =  300 , loss_val =  1.3690708e-05
# epochs =  39 , step =  400 , loss_val =  0.004178111
# epochs =  39 , step =  500 , loss_val =  0.0004455013
# epochs =  40 , step =  0 , loss_val =  0.0003297116
# epochs =  40 , step =  100 , loss_val =  0.00024257092
# epochs =  40 , step =  200 , loss_val =  6.117704e-05
# epochs =  40 , step =  300 , loss_val =  1.1765362e-06
# epochs =  40 , step =  400 , loss_val =  3.09944e-08
# epochs =  40 , step =  500 , loss_val =  4.6967943e-07
# epochs =  41 , step =  0 , loss_val =  0.0017328954
# epochs =  41 , step =  100 , loss_val =  5.1736316e-07
# epochs =  41 , step =  200 , loss_val =  0.0003445113
# epochs =  41 , step =  300 , loss_val =  2.632024e-06
# epochs =  41 , step =  400 , loss_val =  9.444467e-06
# epochs =  41 , step =  500 , loss_val =  3.9860086e-05
# epochs =  42 , step =  0 , loss_val =  1.6689228e-07
# epochs =  42 , step =  100 , loss_val =  1.2385347e-06
# epochs =  42 , step =  200 , loss_val =  6.3537766e-07
# epochs =  42 , step =  300 , loss_val =  1.7975511e-06
# epochs =  42 , step =  400 , loss_val =  2.591024e-05
# epochs =  42 , step =  500 , loss_val =  1.52445045e-05
# epochs =  43 , step =  0 , loss_val =  0.0011105028
# epochs =  43 , step =  100 , loss_val =  1.02259455e-05
# epochs =  43 , step =  200 , loss_val =  4.6001445e-05
# epochs =  43 , step =  300 , loss_val =  3.5285652e-07
# epochs =  43 , step =  400 , loss_val =  0.02085313
# epochs =  43 , step =  500 , loss_val =  4.368532e-06
# epochs =  44 , step =  0 , loss_val =  0.0042978884
# epochs =  44 , step =  100 , loss_val =  3.116491e-05
# epochs =  44 , step =  200 , loss_val =  0.00020166591
# epochs =  44 , step =  300 , loss_val =  0.00015624838
# epochs =  44 , step =  400 , loss_val =  0.00879539
# epochs =  44 , step =  500 , loss_val =  8.225172e-07
# epochs =  45 , step =  0 , loss_val =  0.00095254986
# epochs =  45 , step =  100 , loss_val =  3.039811e-07
# epochs =  45 , step =  200 , loss_val =  7.702931e-06
# epochs =  45 , step =  300 , loss_val =  4.5301676e-05
# epochs =  45 , step =  400 , loss_val =  0.0066724108
# epochs =  45 , step =  500 , loss_val =  0.019332577
# epochs =  46 , step =  0 , loss_val =  8.513641e-06
# epochs =  46 , step =  100 , loss_val =  5.1167276e-06
# epochs =  46 , step =  200 , loss_val =  0.0017325677
# epochs =  46 , step =  300 , loss_val =  3.218647e-08
# epochs =  46 , step =  400 , loss_val =  3.3601547e-05
# epochs =  46 , step =  500 , loss_val =  9.751861e-06
# epochs =  47 , step =  0 , loss_val =  3.5762784e-09
# epochs =  47 , step =  100 , loss_val =  3.5166377e-07
# epochs =  47 , step =  200 , loss_val =  1.6438289e-06
# epochs =  47 , step =  300 , loss_val =  4.768371e-09
# epochs =  47 , step =  400 , loss_val =  1.275533e-07
# epochs =  47 , step =  500 , loss_val =  4.4496443e-05
# epochs =  48 , step =  0 , loss_val =  5.9298272e-06
# epochs =  48 , step =  100 , loss_val =  7.6293794e-08
# epochs =  48 , step =  200 , loss_val =  9.75086e-07
# epochs =  48 , step =  300 , loss_val =  1.3828245e-07
# epochs =  48 , step =  400 , loss_val =  3.5258875e-06
# epochs =  48 , step =  500 , loss_val =  1.1205637e-07
# epochs =  49 , step =  0 , loss_val =  3.6954307e-07
# epochs =  49 , step =  100 , loss_val =  1.8488537e-06
# epochs =  49 , step =  200 , loss_val =  0.0
# epochs =  49 , step =  300 , loss_val =  2.5103873e-06
# epochs =  49 , step =  400 , loss_val =  3.9457584e-07
# epochs =  49 , step =  500 , loss_val =  8.702262e-08
#
# elapsed time =  0:01:46.268401
#
# Accuracy =  0.9933
# type(accuracy_val) =  <class 'numpy.float32'> , type(predicted_list_val) =  <class 'numpy.ndarray'> , type(index_label) =  <class 'numpy.ndarray'>
# index_label.shape =  (10000,)
# length of index_label_list =  10000
# false label count =  67
#
# length of index_label_false_list 67
