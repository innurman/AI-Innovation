# %% [markdown]
# ### [예제 7_1]  1 conv / 2 FC
#
# #### 1 conv, 1 flatten layer, 1 hidden layer

# %%
# colab 에서 tensorflow 1.x 실행
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime      # datetime.now() 를 이용하여 학습 경과 시간 측정

# read_data_sets() 를 통해 데이터를 객체형태로 받아오고
# one_hot 옵션을 통해 정답(label) 을 one-hot 인코딩된 형태로 받아옴

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# mnist 데이터 셋은 train, test, validation 3개의 데이터 셋으로 구성되어 있으며.
# num_examples 값을 통해 데이터의 갯수 확인 가능함

print("\n", mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

# 데이터는 784(28x28)개의 픽셀을 가지는 이미지와
# 10(0~9)개 클래스를 가지는 one-hot 인코딩된 레이블(정답)을 가지고 있음

print("\ntrain image shape = ", np.shape(mnist.train.images))
print("train label shape = ", np.shape(mnist.train.labels))
print("test image shape = ", np.shape(mnist.test.images))
print("test label shape = ", np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-2-37edfc5623ff>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
# Hyper-Parameter
learning_rate = 0.001  # 학습율
epochs = 50            # 반복횟수
batch_size = 100      # 한번에 입력으로 주어지는 MNIST 개수

# %%
# 입력과 정답을 위한 플레이스홀더 정의
X = tf.placeholder(tf.float32, [None, 784]) 

T = tf.placeholder(tf.float32, [None, 10])  

A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])   # image 28X28X1 (black/white)

# %%
# 1번째 컨볼루션 층, 5X5X128 필터
W2 = tf.Variable(tf.random_normal([5, 5, 1, 128], stddev=0.01))  
b2 = tf.Variable(tf.constant(0.1, shape=[128]))   

# 1번째 컨볼루션 연산을 통해 28 X 28 X 1  => 28 X 28 X 128 
C2 = tf.nn.conv2d(A1, W2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 128  => 14 X 14 X 128 
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 완전연결층, 14X14X128개 입력 출력은 256개 의 은닉층 개념
A2_flat = P2_flat = tf.reshape(A2, [-1, 14*14*128])

W3 = tf.Variable(tf.random_normal([14*14*128, 256], stddev=0.01))
b3 = tf.Variable(tf.random_normal([256]))

Z3 = tf.matmul(A2_flat, W3) + b3

A3 = tf.nn.relu(Z3)

# %%
# 출력층
W4 = tf.Variable(tf.random_normal([256, 10], stddev=0.01))
b4 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z4, 즉 softmax 에 들어가는 입력 값
Z4 = logits = tf.matmul(A3, W4) + b4

y = A4 = tf.nn.softmax(Z4)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z4, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A4, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# %%
with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    # 50 번 반복수행
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val = sess.run([accuracy], feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
# Out:
# epochs =  0 , step =  0 , loss_val =  2.5438006
# epochs =  0 , step =  100 , loss_val =  0.32768455
# epochs =  0 , step =  200 , loss_val =  0.18913984
# epochs =  0 , step =  300 , loss_val =  0.13535205
# epochs =  0 , step =  400 , loss_val =  0.052524135
# epochs =  0 , step =  500 , loss_val =  0.10631793
# epochs =  1 , step =  0 , loss_val =  0.1365407
# epochs =  1 , step =  100 , loss_val =  0.03779699
# epochs =  1 , step =  200 , loss_val =  0.053551022
# epochs =  1 , step =  300 , loss_val =  0.087820366
# epochs =  1 , step =  400 , loss_val =  0.079035744
# epochs =  1 , step =  500 , loss_val =  0.04283953
# epochs =  2 , step =  0 , loss_val =  0.04220063
# epochs =  2 , step =  100 , loss_val =  0.10293896
# epochs =  2 , step =  200 , loss_val =  0.1311772
# epochs =  2 , step =  300 , loss_val =  0.095114544
# epochs =  2 , step =  400 , loss_val =  0.11763204
# epochs =  2 , step =  500 , loss_val =  0.06789113
# epochs =  3 , step =  0 , loss_val =  0.13021399
# epochs =  3 , step =  100 , loss_val =  0.031068597
# epochs =  3 , step =  200 , loss_val =  0.022233361
# epochs =  3 , step =  300 , loss_val =  0.065719955
# epochs =  3 , step =  400 , loss_val =  0.017564815
# epochs =  3 , step =  500 , loss_val =  0.010013958
# epochs =  4 , step =  0 , loss_val =  0.070525646
# epochs =  4 , step =  100 , loss_val =  0.015289099
# epochs =  4 , step =  200 , loss_val =  0.030540226
# epochs =  4 , step =  300 , loss_val =  0.06682638
# epochs =  4 , step =  400 , loss_val =  0.013132686
# epochs =  4 , step =  500 , loss_val =  0.015165294
# epochs =  5 , step =  0 , loss_val =  0.091647856
# epochs =  5 , step =  100 , loss_val =  0.0034855446
# epochs =  5 , step =  200 , loss_val =  0.017489078
# epochs =  5 , step =  300 , loss_val =  0.021422632
# epochs =  5 , step =  400 , loss_val =  0.023736406
# epochs =  5 , step =  500 , loss_val =  0.018191995
# epochs =  6 , step =  0 , loss_val =  0.00057882466
# epochs =  6 , step =  100 , loss_val =  0.0077308062
# epochs =  6 , step =  200 , loss_val =  0.028216861
# epochs =  6 , step =  300 , loss_val =  0.024189131
# epochs =  6 , step =  400 , loss_val =  0.0044496628
# epochs =  6 , step =  500 , loss_val =  0.019301284
# epochs =  7 , step =  0 , loss_val =  0.009698205
# epochs =  7 , step =  100 , loss_val =  0.0049830065
# epochs =  7 , step =  200 , loss_val =  0.0074526235
# epochs =  7 , step =  300 , loss_val =  0.0016023245
# epochs =  7 , step =  400 , loss_val =  0.018614084
# epochs =  7 , step =  500 , loss_val =  0.013949253
# epochs =  8 , step =  0 , loss_val =  0.00809769
# epochs =  8 , step =  100 , loss_val =  0.0013491575
# epochs =  8 , step =  200 , loss_val =  0.0090286555
# epochs =  8 , step =  300 , loss_val =  0.02208285
# epochs =  8 , step =  400 , loss_val =  0.00040449578
# epochs =  8 , step =  500 , loss_val =  0.033291027
# epochs =  9 , step =  0 , loss_val =  0.014180107
# epochs =  9 , step =  100 , loss_val =  0.0011861888
# epochs =  9 , step =  200 , loss_val =  0.002383647
# epochs =  9 , step =  300 , loss_val =  0.001230567
# epochs =  9 , step =  400 , loss_val =  0.03232215
# epochs =  9 , step =  500 , loss_val =  0.0063329963
# epochs =  10 , step =  0 , loss_val =  0.0011701891
# epochs =  10 , step =  100 , loss_val =  0.016062586
# epochs =  10 , step =  200 , loss_val =  0.0019870228
# epochs =  10 , step =  300 , loss_val =  0.0019063099
# epochs =  10 , step =  400 , loss_val =  0.0017906362
# epochs =  10 , step =  500 , loss_val =  0.0013837797
# epochs =  11 , step =  0 , loss_val =  0.0072211386
# epochs =  11 , step =  100 , loss_val =  0.0016400836
# epochs =  11 , step =  200 , loss_val =  0.0037479
# epochs =  11 , step =  300 , loss_val =  0.00063218595
# epochs =  11 , step =  400 , loss_val =  0.013209088
# epochs =  11 , step =  500 , loss_val =  0.0023891642
# epochs =  12 , step =  0 , loss_val =  0.0001093104
# epochs =  12 , step =  100 , loss_val =  0.0014447025
# epochs =  12 , step =  200 , loss_val =  0.0053939302
# epochs =  12 , step =  300 , loss_val =  0.0031996155
# epochs =  12 , step =  400 , loss_val =  0.006777307
# epochs =  12 , step =  500 , loss_val =  0.00022635689
# epochs =  13 , step =  0 , loss_val =  6.0771596e-05
# epochs =  13 , step =  100 , loss_val =  0.0031808766
# epochs =  13 , step =  200 , loss_val =  0.039560962
# epochs =  13 , step =  300 , loss_val =  0.0014492592
# epochs =  13 , step =  400 , loss_val =  0.02318844
# epochs =  13 , step =  500 , loss_val =  2.9821449e-05
# epochs =  14 , step =  0 , loss_val =  0.006844266
# epochs =  14 , step =  100 , loss_val =  0.0035305023
# epochs =  14 , step =  200 , loss_val =  0.00012359177
# epochs =  14 , step =  300 , loss_val =  0.024633544
# epochs =  14 , step =  400 , loss_val =  0.004693628
# epochs =  14 , step =  500 , loss_val =  0.0010695796
# epochs =  15 , step =  0 , loss_val =  0.00061514945
# epochs =  15 , step =  100 , loss_val =  1.808297e-05
# epochs =  15 , step =  200 , loss_val =  7.949939e-05
# epochs =  15 , step =  300 , loss_val =  1.6228132e-05
# epochs =  15 , step =  400 , loss_val =  0.0047357515
# epochs =  15 , step =  500 , loss_val =  0.003547079
# epochs =  16 , step =  0 , loss_val =  0.00067293795
# epochs =  16 , step =  100 , loss_val =  0.0018184818
# epochs =  16 , step =  200 , loss_val =  0.00024881578
# epochs =  16 , step =  300 , loss_val =  0.011644414
# epochs =  16 , step =  400 , loss_val =  0.0005201502
# epochs =  16 , step =  500 , loss_val =  0.0085584745
# epochs =  17 , step =  0 , loss_val =  0.00013082133
# epochs =  17 , step =  100 , loss_val =  0.0031829572
# epochs =  17 , step =  200 , loss_val =  2.0193493e-05
# epochs =  17 , step =  300 , loss_val =  0.003544907
# epochs =  17 , step =  400 , loss_val =  7.617127e-05
# epochs =  17 , step =  500 , loss_val =  3.6452486e-06
# epochs =  18 , step =  0 , loss_val =  0.06249106
# epochs =  18 , step =  100 , loss_val =  0.00011430958
# epochs =  18 , step =  200 , loss_val =  0.0031337372
# epochs =  18 , step =  300 , loss_val =  4.7787557e-06
# epochs =  18 , step =  400 , loss_val =  0.0026665232
# epochs =  18 , step =  500 , loss_val =  0.0013780748
# epochs =  19 , step =  0 , loss_val =  0.00056585605
# epochs =  19 , step =  100 , loss_val =  0.0002946373
# epochs =  19 , step =  200 , loss_val =  0.00074217067
# epochs =  19 , step =  300 , loss_val =  0.0020637617
# epochs =  19 , step =  400 , loss_val =  0.07268898
# epochs =  19 , step =  500 , loss_val =  0.0037649884
# epochs =  20 , step =  0 , loss_val =  0.00019545016
# epochs =  20 , step =  100 , loss_val =  0.0002805575
# epochs =  20 , step =  200 , loss_val =  7.8131074e-05
# epochs =  20 , step =  300 , loss_val =  5.5369974e-06
# epochs =  20 , step =  400 , loss_val =  0.001146731
# epochs =  20 , step =  500 , loss_val =  0.0006605202
# epochs =  21 , step =  0 , loss_val =  1.28732145e-05
# epochs =  21 , step =  100 , loss_val =  0.000649586
# epochs =  21 , step =  200 , loss_val =  0.0006444463
# epochs =  21 , step =  300 , loss_val =  0.00014116948
# epochs =  21 , step =  400 , loss_val =  1.1437342e-05
# epochs =  21 , step =  500 , loss_val =  0.00060740486
# epochs =  22 , step =  0 , loss_val =  7.701141e-06
# epochs =  22 , step =  100 , loss_val =  5.5614786e-05
# epochs =  22 , step =  200 , loss_val =  0.0002904565
# epochs =  22 , step =  300 , loss_val =  0.00057363766
# epochs =  22 , step =  400 , loss_val =  7.262163e-05
# epochs =  22 , step =  500 , loss_val =  0.002566246
# epochs =  23 , step =  0 , loss_val =  0.01939602
# epochs =  23 , step =  100 , loss_val =  7.098568e-06
# epochs =  23 , step =  200 , loss_val =  6.160531e-05
# epochs =  23 , step =  300 , loss_val =  3.0592666e-05
# epochs =  23 , step =  400 , loss_val =  8.607141e-05
# epochs =  23 , step =  500 , loss_val =  8.0668004e-05
# epochs =  24 , step =  0 , loss_val =  2.3919994e-05
# epochs =  24 , step =  100 , loss_val =  0.014631953
# epochs =  24 , step =  200 , loss_val =  0.00075953087
# epochs =  24 , step =  300 , loss_val =  0.0024610672
# epochs =  24 , step =  400 , loss_val =  0.0005820712
# epochs =  24 , step =  500 , loss_val =  8.484092e-05
# epochs =  25 , step =  0 , loss_val =  9.901813e-06
# epochs =  25 , step =  100 , loss_val =  0.003243178
# epochs =  25 , step =  200 , loss_val =  3.6107533e-06
# epochs =  25 , step =  300 , loss_val =  0.06312861
# epochs =  25 , step =  400 , loss_val =  0.029857397
# epochs =  25 , step =  500 , loss_val =  2.9494835e-05
# epochs =  26 , step =  0 , loss_val =  0.0001285651
# epochs =  26 , step =  100 , loss_val =  0.0001814792
# epochs =  26 , step =  200 , loss_val =  1.4760207e-05
# epochs =  26 , step =  300 , loss_val =  5.5377794e-05
# epochs =  26 , step =  400 , loss_val =  7.8618265e-05
# epochs =  26 , step =  500 , loss_val =  3.399672e-06
# epochs =  27 , step =  0 , loss_val =  4.2107826e-05
# epochs =  27 , step =  100 , loss_val =  0.000101167665
# epochs =  27 , step =  200 , loss_val =  6.757077e-05
# epochs =  27 , step =  300 , loss_val =  3.316092e-05
# epochs =  27 , step =  400 , loss_val =  2.5521898e-05
# epochs =  27 , step =  500 , loss_val =  1.3233334e-05
# epochs =  28 , step =  0 , loss_val =  2.8439297e-05
# epochs =  28 , step =  100 , loss_val =  8.987164e-06
# epochs =  28 , step =  200 , loss_val =  9.862258e-06
# epochs =  28 , step =  300 , loss_val =  6.743124e-05
# epochs =  28 , step =  400 , loss_val =  1.0683243e-05
# epochs =  28 , step =  500 , loss_val =  4.857195e-06
# epochs =  29 , step =  0 , loss_val =  2.148081e-06
# epochs =  29 , step =  100 , loss_val =  1.2516945e-07
# epochs =  29 , step =  200 , loss_val =  7.758541e-06
# epochs =  29 , step =  300 , loss_val =  1.006112e-06
# epochs =  29 , step =  400 , loss_val =  2.4631381e-05
# epochs =  29 , step =  500 , loss_val =  1.3911216e-06
# epochs =  30 , step =  0 , loss_val =  1.822681e-06
# epochs =  30 , step =  100 , loss_val =  9.369674e-07
# epochs =  30 , step =  200 , loss_val =  6.9037733e-06
# epochs =  30 , step =  300 , loss_val =  7.247716e-07
# epochs =  30 , step =  400 , loss_val =  1.3589266e-06
# epochs =  30 , step =  500 , loss_val =  9.183339e-06
# epochs =  31 , step =  0 , loss_val =  1.3463652e-05
# epochs =  31 , step =  100 , loss_val =  5.4400903e-06
# epochs =  31 , step =  200 , loss_val =  1.311302e-08
# epochs =  31 , step =  300 , loss_val =  1.2485514e-05
# epochs =  31 , step =  400 , loss_val =  6.604139e-06
# epochs =  31 , step =  500 , loss_val =  5.584237e-06
# epochs =  32 , step =  0 , loss_val =  7.303575e-06
# epochs =  32 , step =  100 , loss_val =  2.4495985e-06
# epochs =  32 , step =  200 , loss_val =  1.9432768e-05
# epochs =  32 , step =  300 , loss_val =  2.3370336e-05
# epochs =  32 , step =  400 , loss_val =  4.6009213e-06
# epochs =  32 , step =  500 , loss_val =  4.8673824e-06
# epochs =  33 , step =  0 , loss_val =  9.76978e-06
# epochs =  33 , step =  100 , loss_val =  6.484885e-07
# epochs =  33 , step =  200 , loss_val =  5.945879e-06
# epochs =  33 , step =  300 , loss_val =  2.4901433e-06
# epochs =  33 , step =  400 , loss_val =  9.656081e-06
# epochs =  33 , step =  500 , loss_val =  4.8203883e-06
# epochs =  34 , step =  0 , loss_val =  9.417515e-08
# epochs =  34 , step =  100 , loss_val =  2.5555803e-06
# epochs =  34 , step =  200 , loss_val =  1.1920884e-07
# epochs =  34 , step =  300 , loss_val =  5.125995e-08
# epochs =  34 , step =  400 , loss_val =  8.261026e-07
# epochs =  34 , step =  500 , loss_val =  1.6570043e-07
# epochs =  35 , step =  0 , loss_val =  1.9286754e-06
# epochs =  35 , step =  100 , loss_val =  5.654392e-06
# epochs =  35 , step =  200 , loss_val =  2.9619443e-06
# epochs =  35 , step =  300 , loss_val =  1.0728816e-07
# epochs =  35 , step =  400 , loss_val =  6.425264e-07
# epochs =  35 , step =  500 , loss_val =  1.19209265e-08
# epochs =  36 , step =  0 , loss_val =  6.0796174e-07
# epochs =  36 , step =  100 , loss_val =  1.1177813e-05
# epochs =  36 , step =  200 , loss_val =  7.67687e-07
# epochs =  36 , step =  300 , loss_val =  2.1492335e-06
# epochs =  36 , step =  400 , loss_val =  1.2082865e-05
# epochs =  36 , step =  500 , loss_val =  2.2649756e-08
# epochs =  37 , step =  0 , loss_val =  1.5711271e-06
# epochs =  37 , step =  100 , loss_val =  5.519326e-07
# epochs =  37 , step =  200 , loss_val =  3.504731e-07
# epochs =  37 , step =  300 , loss_val =  7.748591e-08
# epochs =  37 , step =  400 , loss_val =  6.40144e-07
# epochs =  37 , step =  500 , loss_val =  7.3089345e-06
# epochs =  38 , step =  0 , loss_val =  2.8570796e-06
# epochs =  38 , step =  100 , loss_val =  3.881046e-06
# epochs =  38 , step =  200 , loss_val =  5.2770165e-06
# epochs =  38 , step =  300 , loss_val =  1.213481e-06
# epochs =  38 , step =  400 , loss_val =  1.2159302e-07
# epochs =  38 , step =  500 , loss_val =  3.0874799e-07
# epochs =  39 , step =  0 , loss_val =  2.490111e-06
# epochs =  39 , step =  100 , loss_val =  6.091509e-07
# epochs =  39 , step =  200 , loss_val =  2.2337415e-06
# epochs =  39 , step =  300 , loss_val =  3.5881823e-07
# epochs =  39 , step =  400 , loss_val =  1.5258729e-07
# epochs =  39 , step =  500 , loss_val =  5.6384954e-07
# epochs =  40 , step =  0 , loss_val =  5.6028288e-08
# epochs =  40 , step =  100 , loss_val =  8.129887e-07
# epochs =  40 , step =  200 , loss_val =  2.0265456e-07
# epochs =  40 , step =  300 , loss_val =  1.3279391e-06
# epochs =  40 , step =  400 , loss_val =  5.578935e-07
# epochs =  40 , step =  500 , loss_val =  2.3326543e-06
# epochs =  41 , step =  0 , loss_val =  1.4852975e-06
# epochs =  41 , step =  100 , loss_val =  5.2452016e-08
# epochs =  41 , step =  200 , loss_val =  2.8967648e-07
# epochs =  41 , step =  300 , loss_val =  2.7656372e-07
# epochs =  41 , step =  400 , loss_val =  1.8715723e-07
# epochs =  41 , step =  500 , loss_val =  3.5762278e-07
# epochs =  42 , step =  0 , loss_val =  1.0609588e-07
# epochs =  42 , step =  100 , loss_val =  1.2874543e-07
# epochs =  42 , step =  200 , loss_val =  6.0796644e-08
# epochs =  42 , step =  300 , loss_val =  4.243804e-07
# epochs =  42 , step =  400 , loss_val =  8.344648e-09
# epochs =  42 , step =  500 , loss_val =  1.8835017e-07
# epochs =  43 , step =  0 , loss_val =  9.0119516e-07
# epochs =  43 , step =  100 , loss_val =  4.911362e-07
# epochs =  43 , step =  200 , loss_val =  2.849898e-06
# epochs =  43 , step =  300 , loss_val =  1.6808376e-07
# epochs =  43 , step =  400 , loss_val =  2.1576783e-07
# epochs =  43 , step =  500 , loss_val =  3.206695e-07
# epochs =  44 , step =  0 , loss_val =  6.675704e-08
# epochs =  44 , step =  100 , loss_val =  1.2636109e-07
# epochs =  44 , step =  200 , loss_val =  8.547165e-07
# epochs =  44 , step =  300 , loss_val =  1.6306565e-06
# epochs =  44 , step =  400 , loss_val =  2.1099855e-07
# epochs =  44 , step =  500 , loss_val =  1.07287995e-07
# epochs =  45 , step =  0 , loss_val =  4.4703128e-07
# epochs =  45 , step =  100 , loss_val =  4.9471083e-07
# epochs =  45 , step =  200 , loss_val =  9.0598824e-08
# epochs =  45 , step =  300 , loss_val =  8.3446224e-08
# epochs =  45 , step =  400 , loss_val =  1.7881389e-08
# epochs =  45 , step =  500 , loss_val =  2.914347e-06
# epochs =  46 , step =  0 , loss_val =  5.8411666e-07
# epochs =  46 , step =  100 , loss_val =  4.0531106e-08
# epochs =  46 , step =  200 , loss_val =  4.768371e-09
# epochs =  46 , step =  300 , loss_val =  9.667659e-07
# epochs =  46 , step =  400 , loss_val =  2.622586e-07
# epochs =  46 , step =  500 , loss_val =  6.1987885e-07
# epochs =  47 , step =  0 , loss_val =  4.1603624e-07
# epochs =  47 , step =  100 , loss_val =  9.5367206e-08
# epochs =  47 , step =  200 , loss_val =  4.7325383e-07
# epochs =  47 , step =  300 , loss_val =  4.267641e-07
# epochs =  47 , step =  400 , loss_val =  3.457066e-08
# epochs =  47 , step =  500 , loss_val =  1.2516922e-07
# epochs =  48 , step =  0 , loss_val =  0.015344319
# epochs =  48 , step =  100 , loss_val =  0.00059201487
# epochs =  48 , step =  200 , loss_val =  0.018999072
# epochs =  48 , step =  300 , loss_val =  0.0005301068
# epochs =  48 , step =  400 , loss_val =  0.0002015462
# epochs =  48 , step =  500 , loss_val =  0.0120134745
# epochs =  49 , step =  0 , loss_val =  8.381681e-06
# epochs =  49 , step =  100 , loss_val =  1.3442536e-05
# epochs =  49 , step =  200 , loss_val =  2.5544823e-06
# epochs =  49 , step =  300 , loss_val =  0.00020273044
# epochs =  49 , step =  400 , loss_val =  3.349743e-07
# epochs =  49 , step =  500 , loss_val =  0.00023288716
#
# elapsed time =  0:06:55.711379
#
# Accuracy =  [0.989]
