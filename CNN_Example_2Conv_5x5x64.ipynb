# %% [markdown]
# [예제 4_2]
# 2 conv / 1 flatten CNN 구조를 이용하여 index_label_prediction 값을 출력하는 코드를 구현하고. 필터 개수가 변화할 때 기존 코드의 어느 부분이 변경되는지 확인하시오

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime      # datetime.now() 를 이용하여 학습 경과 시간 측정

# read_data_sets() 를 통해 데이터를 객체형태로 받아오고
# one_hot 옵션을 통해 정답(label) 을 one-hot 인코딩된 형태로 받아옴

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# mnist 데이터 셋은 train, test, validation 3개의 데이터 셋으로 구성되어 있으며.
# num_examples 값을 통해 데이터의 갯수 확인 가능함

print("\n", mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

# 데이터는 784(28x28)개의 픽셀을 가지는 이미지와
# 10(0~9)개 클래스를 가지는 one-hot 인코딩된 레이블(정답)을 가지고 있음

print("\ntrain image shape = ", np.shape(mnist.train.images))
print("train label shape = ", np.shape(mnist.train.labels))
print("test image shape = ", np.shape(mnist.test.images))
print("test label shape = ", np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-2-37edfc5623ff>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
# Hyper-Parameter
learning_rate = 0.001  # 학습율
epochs = 50            # 반복횟수
batch_size = 100      # 한번에 입력으로 주어지는 MNIST 개수

# %%
# 입력과 정답을 위한 플레이스홀더 정의
X = tf.placeholder(tf.float32, [None, 784])  

A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])   # image 28X28X1 (black/white)


T = tf.placeholder(tf.float32, [None, 10])

# %%
# 1번째 컨볼루션 층
W2 = tf.Variable(tf.random_normal([5, 5, 1, 32], stddev=0.01))  
b2 = tf.Variable(tf.constant(0.1, shape=[32]))   

# 1번째 컨볼루션 연산을 통해 28 X 28 X1  => 28 X 28 X 32 
C2 = tf.nn.conv2d(A1, W2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 32  => 14 X 14 X 32 
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 2번째 컨볼루션 층,  5X5X64
W3 = tf.Variable(tf.random_normal([5, 5, 32, 64], stddev=0.01))  
b3 = tf.Variable(tf.constant(0.1, shape=[64]))   

# 2번째 컨볼루션 연산을 통해 14 X 14 X 32 => 14 X 14 X 64 
C3 = tf.nn.conv2d(A2, W3, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z3 = tf.nn.relu(C3+b3)

# 2번째 max pooling을 통해 14 X 14 X 64 => 7 X 7 X 64
A3 = P3 = tf.nn.max_pool(Z3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 7X7 크기를 가진 64개의 activation map을 flatten 시킴
A3_flat = P3_flat = tf.reshape(A3, [-1, 7*7*64])

# %%
# 출력층
W4 = tf.Variable(tf.random_normal([7*7*64, 10], stddev=0.01))
b4 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z4, 즉 softmax 에 들어가는 입력 값
Z4 = logits = tf.matmul(A3_flat, W4) + b4    # 선형회귀 값 Z4

y = A4 = tf.nn.softmax(Z4)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z4, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A4, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# %%
with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val  = sess.run([accuracy], feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
# Out:
# epochs =  0 , step =  0 , loss_val =  2.8057635
# epochs =  0 , step =  100 , loss_val =  0.31143293
# epochs =  0 , step =  200 , loss_val =  0.15674587
# epochs =  0 , step =  300 , loss_val =  0.06920407
# epochs =  0 , step =  400 , loss_val =  0.15817426
# epochs =  0 , step =  500 , loss_val =  0.10500563
# epochs =  1 , step =  0 , loss_val =  0.068918556
# epochs =  1 , step =  100 , loss_val =  0.07239395
# epochs =  1 , step =  200 , loss_val =  0.095812626
# epochs =  1 , step =  300 , loss_val =  0.07088007
# epochs =  1 , step =  400 , loss_val =  0.118368894
# epochs =  1 , step =  500 , loss_val =  0.09665221
# epochs =  2 , step =  0 , loss_val =  0.039557863
# epochs =  2 , step =  100 , loss_val =  0.053946506
# epochs =  2 , step =  200 , loss_val =  0.11781508
# epochs =  2 , step =  300 , loss_val =  0.039158296
# epochs =  2 , step =  400 , loss_val =  0.054181565
# epochs =  2 , step =  500 , loss_val =  0.04500489
# epochs =  3 , step =  0 , loss_val =  0.09365587
# epochs =  3 , step =  100 , loss_val =  0.024587454
# epochs =  3 , step =  200 , loss_val =  0.05380395
# epochs =  3 , step =  300 , loss_val =  0.006437497
# epochs =  3 , step =  400 , loss_val =  0.020527465
# epochs =  3 , step =  500 , loss_val =  0.030882392
# epochs =  4 , step =  0 , loss_val =  0.008141504
# epochs =  4 , step =  100 , loss_val =  0.026789837
# epochs =  4 , step =  200 , loss_val =  0.019851571
# epochs =  4 , step =  300 , loss_val =  0.05136723
# epochs =  4 , step =  400 , loss_val =  0.033448227
# epochs =  4 , step =  500 , loss_val =  0.004178335
# epochs =  5 , step =  0 , loss_val =  0.0062214523
# epochs =  5 , step =  100 , loss_val =  0.065023825
# epochs =  5 , step =  200 , loss_val =  0.09415672
# epochs =  5 , step =  300 , loss_val =  0.055628978
# epochs =  5 , step =  400 , loss_val =  0.061098427
# epochs =  5 , step =  500 , loss_val =  0.015743114
# epochs =  6 , step =  0 , loss_val =  0.016049085
# epochs =  6 , step =  100 , loss_val =  0.07118023
# epochs =  6 , step =  200 , loss_val =  0.0960782
# epochs =  6 , step =  300 , loss_val =  0.012715102
# epochs =  6 , step =  400 , loss_val =  0.013496261
# epochs =  6 , step =  500 , loss_val =  0.016546542
# epochs =  7 , step =  0 , loss_val =  0.022161143
# epochs =  7 , step =  100 , loss_val =  0.0032009394
# epochs =  7 , step =  200 , loss_val =  0.040953387
# epochs =  7 , step =  300 , loss_val =  0.020634852
# epochs =  7 , step =  400 , loss_val =  0.0054721516
# epochs =  7 , step =  500 , loss_val =  0.0020677352
# epochs =  8 , step =  0 , loss_val =  0.006199954
# epochs =  8 , step =  100 , loss_val =  0.006024133
# epochs =  8 , step =  200 , loss_val =  0.024826432
# epochs =  8 , step =  300 , loss_val =  0.021529783
# epochs =  8 , step =  400 , loss_val =  0.039138075
# epochs =  8 , step =  500 , loss_val =  0.0358606
# epochs =  9 , step =  0 , loss_val =  0.00828492
# epochs =  9 , step =  100 , loss_val =  0.010479173
# epochs =  9 , step =  200 , loss_val =  0.0021093474
# epochs =  9 , step =  300 , loss_val =  0.03445103
# epochs =  9 , step =  400 , loss_val =  0.0015471843
# epochs =  9 , step =  500 , loss_val =  0.0014672317
# epochs =  10 , step =  0 , loss_val =  0.019286226
# epochs =  10 , step =  100 , loss_val =  0.004157393
# epochs =  10 , step =  200 , loss_val =  0.012998619
# epochs =  10 , step =  300 , loss_val =  0.0026487017
# epochs =  10 , step =  400 , loss_val =  0.0026165117
# epochs =  10 , step =  500 , loss_val =  0.010257022
# epochs =  11 , step =  0 , loss_val =  0.006451443
# epochs =  11 , step =  100 , loss_val =  0.0034747387
# epochs =  11 , step =  200 , loss_val =  0.026814602
# epochs =  11 , step =  300 , loss_val =  0.010092843
# epochs =  11 , step =  400 , loss_val =  0.020892464
# epochs =  11 , step =  500 , loss_val =  0.04088223
# epochs =  12 , step =  0 , loss_val =  0.011785265
# epochs =  12 , step =  100 , loss_val =  0.0009615216
# epochs =  12 , step =  200 , loss_val =  0.03298511
# epochs =  12 , step =  300 , loss_val =  0.0009879642
# epochs =  12 , step =  400 , loss_val =  0.0010745447
# epochs =  12 , step =  500 , loss_val =  0.012739333
# epochs =  13 , step =  0 , loss_val =  0.0063321767
# epochs =  13 , step =  100 , loss_val =  0.000535317
# epochs =  13 , step =  200 , loss_val =  0.00029709405
# epochs =  13 , step =  300 , loss_val =  0.012527858
# epochs =  13 , step =  400 , loss_val =  0.001864364
# epochs =  13 , step =  500 , loss_val =  0.0058289045
# epochs =  14 , step =  0 , loss_val =  0.008436697
# epochs =  14 , step =  100 , loss_val =  0.00066306914
# epochs =  14 , step =  200 , loss_val =  0.0059141843
# epochs =  14 , step =  300 , loss_val =  0.011708447
# epochs =  14 , step =  400 , loss_val =  0.004667614
# epochs =  14 , step =  500 , loss_val =  0.001745877
# epochs =  15 , step =  0 , loss_val =  0.0035810664
# epochs =  15 , step =  100 , loss_val =  0.000975959
# epochs =  15 , step =  200 , loss_val =  0.0005209135
# epochs =  15 , step =  300 , loss_val =  0.005929358
# epochs =  15 , step =  400 , loss_val =  0.014554995
# epochs =  15 , step =  500 , loss_val =  0.0019830004
# epochs =  16 , step =  0 , loss_val =  0.0007544831
# epochs =  16 , step =  100 , loss_val =  0.006080795
# epochs =  16 , step =  200 , loss_val =  0.01054372
# epochs =  16 , step =  300 , loss_val =  0.10546549
# epochs =  16 , step =  400 , loss_val =  0.00019177952
# epochs =  16 , step =  500 , loss_val =  0.0035127015
# epochs =  17 , step =  0 , loss_val =  0.0012044923
# epochs =  17 , step =  100 , loss_val =  0.028786559
# epochs =  17 , step =  200 , loss_val =  0.0031825486
# epochs =  17 , step =  300 , loss_val =  0.000111753696
# epochs =  17 , step =  400 , loss_val =  2.1029131e-05
# epochs =  17 , step =  500 , loss_val =  0.013300492
# epochs =  18 , step =  0 , loss_val =  0.0023396527
# epochs =  18 , step =  100 , loss_val =  0.0054454505
# epochs =  18 , step =  200 , loss_val =  0.004759032
# epochs =  18 , step =  300 , loss_val =  0.0056758677
# epochs =  18 , step =  400 , loss_val =  0.0019489828
# epochs =  18 , step =  500 , loss_val =  0.0017388936
# epochs =  19 , step =  0 , loss_val =  0.002776773
# epochs =  19 , step =  100 , loss_val =  0.00043095477
# epochs =  19 , step =  200 , loss_val =  0.0012163954
# epochs =  19 , step =  300 , loss_val =  0.0008882149
# epochs =  19 , step =  400 , loss_val =  0.00018760895
# epochs =  19 , step =  500 , loss_val =  0.023309683
# epochs =  20 , step =  0 , loss_val =  0.000120163786
# epochs =  20 , step =  100 , loss_val =  0.015893439
# epochs =  20 , step =  200 , loss_val =  0.032104947
# epochs =  20 , step =  300 , loss_val =  0.012163085
# epochs =  20 , step =  400 , loss_val =  0.00022382251
# epochs =  20 , step =  500 , loss_val =  0.0032932598
# epochs =  21 , step =  0 , loss_val =  0.00037220877
# epochs =  21 , step =  100 , loss_val =  7.8218094e-05
# epochs =  21 , step =  200 , loss_val =  3.8560087e-05
# epochs =  21 , step =  300 , loss_val =  0.0015938403
# epochs =  21 , step =  400 , loss_val =  0.00066268916
# epochs =  21 , step =  500 , loss_val =  0.012727922
# epochs =  22 , step =  0 , loss_val =  0.0013226839
# epochs =  22 , step =  100 , loss_val =  0.00028711514
# epochs =  22 , step =  200 , loss_val =  0.036869995
# epochs =  22 , step =  300 , loss_val =  0.00088123226
# epochs =  22 , step =  400 , loss_val =  1.0229854e-05
# epochs =  22 , step =  500 , loss_val =  0.00016360595
# epochs =  23 , step =  0 , loss_val =  0.0020573556
# epochs =  23 , step =  100 , loss_val =  0.00041515206
# epochs =  23 , step =  200 , loss_val =  0.0006708315
# epochs =  23 , step =  300 , loss_val =  0.0063476246
# epochs =  23 , step =  400 , loss_val =  0.0011743869
# epochs =  23 , step =  500 , loss_val =  0.0023294461
# epochs =  24 , step =  0 , loss_val =  0.023451932
# epochs =  24 , step =  100 , loss_val =  0.00041574682
# epochs =  24 , step =  200 , loss_val =  0.0051642116
# epochs =  24 , step =  300 , loss_val =  0.00019006517
# epochs =  24 , step =  400 , loss_val =  5.2541207e-05
# epochs =  24 , step =  500 , loss_val =  0.04809686
# epochs =  25 , step =  0 , loss_val =  0.0012689248
# epochs =  25 , step =  100 , loss_val =  0.0006726217
# epochs =  25 , step =  200 , loss_val =  0.001243192
# epochs =  25 , step =  300 , loss_val =  0.0007830409
# epochs =  25 , step =  400 , loss_val =  0.02142645
# epochs =  25 , step =  500 , loss_val =  0.0004155897
# epochs =  26 , step =  0 , loss_val =  2.091289e-05
# epochs =  26 , step =  100 , loss_val =  0.0042195166
# epochs =  26 , step =  200 , loss_val =  0.008058203
# epochs =  26 , step =  300 , loss_val =  9.9447796e-05
# epochs =  26 , step =  400 , loss_val =  0.00012138911
# epochs =  26 , step =  500 , loss_val =  0.0025655932
# epochs =  27 , step =  0 , loss_val =  0.00033181615
# epochs =  27 , step =  100 , loss_val =  0.016657798
# epochs =  27 , step =  200 , loss_val =  1.3924246e-05
# epochs =  27 , step =  300 , loss_val =  0.0004920153
# epochs =  27 , step =  400 , loss_val =  0.00070462184
# epochs =  27 , step =  500 , loss_val =  0.00017689122
# epochs =  28 , step =  0 , loss_val =  0.009096569
# epochs =  28 , step =  100 , loss_val =  0.015405283
# epochs =  28 , step =  200 , loss_val =  4.067196e-05
# epochs =  28 , step =  300 , loss_val =  5.7472116e-05
# epochs =  28 , step =  400 , loss_val =  0.00087961723
# epochs =  28 , step =  500 , loss_val =  0.000532079
# epochs =  29 , step =  0 , loss_val =  0.00035662204
# epochs =  29 , step =  100 , loss_val =  0.0036587298
# epochs =  29 , step =  200 , loss_val =  1.4438209e-05
# epochs =  29 , step =  300 , loss_val =  0.0007129218
# epochs =  29 , step =  400 , loss_val =  0.00014717811
# epochs =  29 , step =  500 , loss_val =  0.021553706
# epochs =  30 , step =  0 , loss_val =  0.00030411675
# epochs =  30 , step =  100 , loss_val =  8.727761e-05
# epochs =  30 , step =  200 , loss_val =  0.00024306506
# epochs =  30 , step =  300 , loss_val =  4.4585424e-05
# epochs =  30 , step =  400 , loss_val =  6.952591e-06
# epochs =  30 , step =  500 , loss_val =  1.385251e-05
# epochs =  31 , step =  0 , loss_val =  0.0004326148
# epochs =  31 , step =  100 , loss_val =  0.033290867
# epochs =  31 , step =  200 , loss_val =  0.00068161666
# epochs =  31 , step =  300 , loss_val =  0.026999144
# epochs =  31 , step =  400 , loss_val =  0.00025469426
# epochs =  31 , step =  500 , loss_val =  6.925031e-05
# epochs =  32 , step =  0 , loss_val =  0.0010317311
# epochs =  32 , step =  100 , loss_val =  0.011544156
# epochs =  32 , step =  200 , loss_val =  0.00018029701
# epochs =  32 , step =  300 , loss_val =  0.000120365665
# epochs =  32 , step =  400 , loss_val =  0.00014091351
# epochs =  32 , step =  500 , loss_val =  0.0054716812
# epochs =  33 , step =  0 , loss_val =  0.0029369371
# epochs =  33 , step =  100 , loss_val =  0.0009418748
# epochs =  33 , step =  200 , loss_val =  5.9454596e-06
# epochs =  33 , step =  300 , loss_val =  2.2117005e-05
# epochs =  33 , step =  400 , loss_val =  2.6530843e-05
# epochs =  33 , step =  500 , loss_val =  0.0006971466
# epochs =  34 , step =  0 , loss_val =  1.3256467e-05
# epochs =  34 , step =  100 , loss_val =  2.963242e-06
# epochs =  34 , step =  200 , loss_val =  0.012949282
# epochs =  34 , step =  300 , loss_val =  0.0019827397
# epochs =  34 , step =  400 , loss_val =  5.7249704e-06
# epochs =  34 , step =  500 , loss_val =  1.7532038e-05
# epochs =  35 , step =  0 , loss_val =  1.2962215e-05
# epochs =  35 , step =  100 , loss_val =  0.0005145232
# epochs =  35 , step =  200 , loss_val =  1.5449242e-06
# epochs =  35 , step =  300 , loss_val =  2.1623803e-06
# epochs =  35 , step =  400 , loss_val =  3.5667632e-05
# epochs =  35 , step =  500 , loss_val =  0.0043265927
# epochs =  36 , step =  0 , loss_val =  1.2409005e-05
# epochs =  36 , step =  100 , loss_val =  0.00021214678
# epochs =  36 , step =  200 , loss_val =  3.5951703e-06
# epochs =  36 , step =  300 , loss_val =  4.772645e-06
# epochs =  36 , step =  400 , loss_val =  4.172285e-07
# epochs =  36 , step =  500 , loss_val =  0.0030287048
# epochs =  37 , step =  0 , loss_val =  0.0016810708
# epochs =  37 , step =  100 , loss_val =  0.0001296433
# epochs =  37 , step =  200 , loss_val =  3.504721e-05
# epochs =  37 , step =  300 , loss_val =  0.0008698981
# epochs =  37 , step =  400 , loss_val =  0.0010630187
# epochs =  37 , step =  500 , loss_val =  0.00068626436
# epochs =  38 , step =  0 , loss_val =  6.590407e-05
# epochs =  38 , step =  100 , loss_val =  0.00041900016
# epochs =  38 , step =  200 , loss_val =  0.0010771556
# epochs =  38 , step =  300 , loss_val =  0.00046654328
# epochs =  38 , step =  400 , loss_val =  8.665282e-05
# epochs =  38 , step =  500 , loss_val =  0.00084852136
# epochs =  39 , step =  0 , loss_val =  0.0025404321
# epochs =  39 , step =  100 , loss_val =  0.00074833224
# epochs =  39 , step =  200 , loss_val =  0.0003597974
# epochs =  39 , step =  300 , loss_val =  0.009195165
# epochs =  39 , step =  400 , loss_val =  0.031315155
# epochs =  39 , step =  500 , loss_val =  6.3131315e-06
# epochs =  40 , step =  0 , loss_val =  0.0057180203
# epochs =  40 , step =  100 , loss_val =  7.4171396e-05
# epochs =  40 , step =  200 , loss_val =  0.0007647753
# epochs =  40 , step =  300 , loss_val =  0.0001558194
# epochs =  40 , step =  400 , loss_val =  5.209403e-07
# epochs =  40 , step =  500 , loss_val =  0.00078385224
# epochs =  41 , step =  0 , loss_val =  0.0010640507
# epochs =  41 , step =  100 , loss_val =  0.0010329403
# epochs =  41 , step =  200 , loss_val =  3.97172e-06
# epochs =  41 , step =  300 , loss_val =  7.896891e-06
# epochs =  41 , step =  400 , loss_val =  8.687364e-06
# epochs =  41 , step =  500 , loss_val =  0.00010827371
# epochs =  42 , step =  0 , loss_val =  0.00012183156
# epochs =  42 , step =  100 , loss_val =  0.009034221
# epochs =  42 , step =  200 , loss_val =  0.00466428
# epochs =  42 , step =  300 , loss_val =  0.0444443
# epochs =  42 , step =  400 , loss_val =  0.00062124967
# epochs =  42 , step =  500 , loss_val =  0.00042342098
# epochs =  43 , step =  0 , loss_val =  0.024460798
# epochs =  43 , step =  100 , loss_val =  4.7543585e-06
# epochs =  43 , step =  200 , loss_val =  2.3349365e-05
# epochs =  43 , step =  300 , loss_val =  2.4150643e-06
# epochs =  43 , step =  400 , loss_val =  7.367232e-06
# epochs =  43 , step =  500 , loss_val =  0.0019575707
# epochs =  44 , step =  0 , loss_val =  1.3594704e-05
# epochs =  44 , step =  100 , loss_val =  4.7130325e-05
# epochs =  44 , step =  200 , loss_val =  0.00028069562
# epochs =  44 , step =  300 , loss_val =  7.4017815e-05
# epochs =  44 , step =  400 , loss_val =  2.156404e-06
# epochs =  44 , step =  500 , loss_val =  0.012456149
# epochs =  45 , step =  0 , loss_val =  0.0010077446
# epochs =  45 , step =  100 , loss_val =  0.000281683
# epochs =  45 , step =  200 , loss_val =  1.9550262e-07
# epochs =  45 , step =  300 , loss_val =  5.2821953e-05
# epochs =  45 , step =  400 , loss_val =  2.5889126e-06
# epochs =  45 , step =  500 , loss_val =  0.011194507
# epochs =  46 , step =  0 , loss_val =  1.3446759e-05
# epochs =  46 , step =  100 , loss_val =  0.00012533292
# epochs =  46 , step =  200 , loss_val =  0.00019371568
# epochs =  46 , step =  300 , loss_val =  2.3279986e-06
# epochs =  46 , step =  400 , loss_val =  7.4266427e-07
# epochs =  46 , step =  500 , loss_val =  4.848318e-06
# epochs =  47 , step =  0 , loss_val =  7.1525568e-09
# epochs =  47 , step =  100 , loss_val =  6.3379807e-06
# epochs =  47 , step =  200 , loss_val =  4.935175e-07
# epochs =  47 , step =  300 , loss_val =  0.00017591668
# epochs =  47 , step =  400 , loss_val =  5.4001333e-07
# epochs =  47 , step =  500 , loss_val =  2.503394e-08
# epochs =  48 , step =  0 , loss_val =  2.604644e-06
# epochs =  48 , step =  100 , loss_val =  3.6057556e-06
# epochs =  48 , step =  200 , loss_val =  1.533409e-05
# epochs =  48 , step =  300 , loss_val =  4.5733825e-05
# epochs =  48 , step =  400 , loss_val =  1.5710153e-05
# epochs =  48 , step =  500 , loss_val =  1.2206665e-06
# epochs =  49 , step =  0 , loss_val =  4.1644985e-06
# epochs =  49 , step =  100 , loss_val =  2.9216994e-06
# epochs =  49 , step =  200 , loss_val =  1.7629442e-05
# epochs =  49 , step =  300 , loss_val =  1.1539237e-06
# epochs =  49 , step =  400 , loss_val =  2.2874901e-05
# epochs =  49 , step =  500 , loss_val =  6.92707e-06
#
# elapsed time =  0:04:03.215608
#
# Accuracy =  [0.9919]
