# %% [markdown]
# ### [예제 3] np.random.rand(..) 이용한 가중치 초기화, 은닉층 노드 1개

# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %matplotlib inline

# 수치미분 함수

def numerical_derivative(f, x):
    delta_x = 1e-4 # 0.0001
    grad = np.zeros_like(x)
    
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    
    while not it.finished:
        idx = it.multi_index        
        tmp_val = x[idx]
        x[idx] = float(tmp_val) + delta_x
        fx1 = f(x) # f(x+delta_x)
        
        x[idx] = float(tmp_val) - delta_x 
        fx2 = f(x) # f(x-delta_x)
        grad[idx] = (fx1 - fx2) / (2*delta_x)
        
        x[idx] = tmp_val 
        it.iternext()   
        
    return grad

# sigmoid 함수

def sigmoid(x):
    return 1 / (1+np.exp(-x))

# %%
# MNIST_Test Class

class MNIST_Test:
    
    # 생성자
    # xdata, tdata => numpy.array(...)
    def __init__(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes
        
        # 은닉층 가중치  W2  Xavier/He 방법으로 self.W2 가중치 초기화
        #self.W2 = np.random.randn(self.input_nodes, self.hidden_nodes) / np.sqrt(self.input_nodes/2)
        #self.b2 = np.random.rand(self.hidden_nodes)      
        
        # 출력층 가중치는 W3  Xavier/He 방법으로 self.W3 가중치 초기화
        #self.W3 = np.random.randn(self.hidden_nodes, self.output_nodes) / np.sqrt(self.hidden_nodes/2)
        #self.b3 = np.random.rand(self.output_nodes)      
        
        # 2층 hidden layer unit 
        # 가중치 W, 바이어스 b 초기화
        self.W2 = np.random.rand(input_nodes, hidden_nodes)  
        self.b2 = np.random.rand(hidden_nodes)
        
        # 3층 output layer unit : 1 개 
        self.W3 = np.random.rand(hidden_nodes,output_nodes)
        self.b3 = np.random.rand(output_nodes)
                        
        # 학습률 learning rate 초기화
        self.learning_rate = learning_rate
        
        print("MNIST_Test object is created !!!")
        
    # 손실함수
    def feed_forward(self):
        
        delta = 1e-7    # log 무한대 발산 방지
    
        z2 = np.dot(self.input_data, self.W2) + self.b2
        a2 = sigmoid(z2)
        
        z3 = np.dot(a2, self.W3) + self.b3
        y = a3 = sigmoid(z3)
    
        # cross-entropy 
        return  -np.sum( self.target_data*np.log(y + delta) + (1-self.target_data)*np.log((1 - y)+delta ) )
    
    # obtain W and b
    def get_W_b(self):
        
        return self.W2,  self.b2, self.W3, self.b3
    
    # 손실 값 계산
    def loss_val(self):
        
        delta = 1e-7    # log 무한대 발산 방지
    
        z2 = np.dot(self.input_data, self.W2) + self.b2
        a2 = sigmoid(z2)
        
        z3 = np.dot(a2, self.W3) + self.b3
        y = a3 = sigmoid(z3)
    
        # cross-entropy 
        return  -np.sum( self.target_data*np.log(y + delta) + (1-self.target_data)*np.log((1 - y)+delta ) )
    
    # query, 즉 미래 값 예측 함수
    def predict(self, input_data):    
        
        z2 = np.dot(input_data, self.W2) + self.b2
        a2 = sigmoid(z2)
        
        z3 = np.dot(a2, self.W3) + self.b3
        y = a3 = sigmoid(z3)
    
        # MNIST 경우는 one-hot encoding 을 적용하기 때문에
        # 0 또는 1 이 아닌 argmax() 를 통해 최대 인덱스를 넘겨주어야 함
        predicted_num = np.argmax(y)
    
        return predicted_num

    # 정확도 측정함수
    def accuracy(self, input_data, target_data):
        
        matched_list = []
        not_matched_list = []
        
        for index in range(len(input_data)):
                        
            label = int(target_data[index])
                        
            # normalize
            data = (input_data[index, :] / 255.0 * 0.99) + 0.01
      
            predicted_num = self.predict(data)
        
            if label == predicted_num:
                matched_list.append(index)
                
            else:
                not_matched_list.append(index)                
                
        accuracy_val = len(matched_list)/(len(input_data))
        
        return accuracy_val, not_matched_list
    
        
    # 수치미분을 이용하여 손실함수가 최소가 될때 까지 학습하는 함수
    def train(self, input_data, target_data):
        
        self.input_data = input_data
        self.target_data = target_data
        
        f = lambda x : self.feed_forward()
        
        self.W2 -= self.learning_rate * numerical_derivative(f, self.W2)
    
        self.b2 -= self.learning_rate * numerical_derivative(f, self.b2)
        
        self.W3 -= self.learning_rate * numerical_derivative(f, self.W3)
    
        self.b3 -= self.learning_rate * numerical_derivative(f, self.b3)

# %%
# training data 

try:
    
    training_data = np.loadtxt('./mnist_train.csv', delimiter=',', dtype=np.float32)

    print("training_data.shape = ", training_data.shape)
    
except Exception as err:
    
    print('Exception occur !!')
# Out:
# training_data.shape =  (60000, 785)

# %%
#hyper-parameter
i_nodes = training_data.shape[1] - 1    # input nodes 개수
h_nodes = 1  # hidden nodes 개수. Test
o_nodes = 10    # output nodes 개수
lr = 1e-2      # learning rate
epochs = 1   # 반복횟수

# 손실함수 값을 저장할 list 생성
loss_val_list = []

# MNIST_Test 객체 생성
obj = MNIST_Test(i_nodes, h_nodes, o_nodes, lr)

print("Neural Network Learning using Numerical Derivative...")

start_time = datetime.now()

for step in range(epochs):
    
    for index in range(len(training_data)):    
                        
        # input_data, target_data normalize    
        input_data = ((training_data[index, 1:] / 255.0) * 0.99) + 0.01
        
        
        target_data = np.zeros(o_nodes) + 0.01    
        target_data[int(training_data[index, 0])] = 0.99
        
        obj.train(input_data, target_data)
                
        if (index % 200 == 0):
            print("epochs = ", step, ", index = ", index, ", loss value = ", obj.loss_val())
            
        # 손실함수 값 저장
        loss_val_list.append(obj.loss_val())        

end_time = datetime.now()
        
print("")
print("Elapsed Time => ", end_time - start_time)
# Out:
# MNIST_Test object is created !!!
# Neural Network Learning using Numerical Derivative...
# epochs =  0 , index =  0 , loss value =  11.57979377596937
# epochs =  0 , index =  200 , loss value =  4.860968406570275
# epochs =  0 , index =  400 , loss value =  3.7350186952787117
# epochs =  0 , index =  600 , loss value =  3.4987206356015683
# epochs =  0 , index =  800 , loss value =  3.44046491665762
# epochs =  0 , index =  1000 , loss value =  3.4946018125634386
# epochs =  0 , index =  1200 , loss value =  3.3098600855335523
# epochs =  0 , index =  1400 , loss value =  3.1936860771272384
# epochs =  0 , index =  1600 , loss value =  3.4981239782220306
# epochs =  0 , index =  1800 , loss value =  3.4190748489002383
# epochs =  0 , index =  2000 , loss value =  3.486246028775734
# epochs =  0 , index =  2200 , loss value =  3.371635526135507
# epochs =  0 , index =  2400 , loss value =  3.4839818629361368
# epochs =  0 , index =  2600 , loss value =  3.5531607474312015
# epochs =  0 , index =  2800 , loss value =  3.376844755176572
# epochs =  0 , index =  3000 , loss value =  3.5729053125221357
# epochs =  0 , index =  3200 , loss value =  3.3543911768783645
# epochs =  0 , index =  3400 , loss value =  3.4287518155946772
# epochs =  0 , index =  3600 , loss value =  3.3963628622863986
# epochs =  0 , index =  3800 , loss value =  3.344885343935827
# epochs =  0 , index =  4000 , loss value =  3.337383916262479
# epochs =  0 , index =  4200 , loss value =  3.3956927033648108
# epochs =  0 , index =  4400 , loss value =  3.3979006562714735
# epochs =  0 , index =  4600 , loss value =  3.619079148202289
# epochs =  0 , index =  4800 , loss value =  3.441805282268428
# epochs =  0 , index =  5000 , loss value =  3.2485854379191452
# epochs =  0 , index =  5200 , loss value =  3.4991945182618522
# epochs =  0 , index =  5400 , loss value =  3.4707140655525284
# epochs =  0 , index =  5600 , loss value =  3.420481217692708
# epochs =  0 , index =  5800 , loss value =  3.4795050273013257
# epochs =  0 , index =  6000 , loss value =  3.2891607445997453
# epochs =  0 , index =  6200 , loss value =  3.5634106764774
# epochs =  0 , index =  6400 , loss value =  3.430753044364672
# epochs =  0 , index =  6600 , loss value =  3.393096085843305
# epochs =  0 , index =  6800 , loss value =  3.3246085741904214
# epochs =  0 , index =  7000 , loss value =  3.4081408953562895
# epochs =  0 , index =  7200 , loss value =  3.3963034258643594
# epochs =  0 , index =  7400 , loss value =  3.4359051419365456
# epochs =  0 , index =  7600 , loss value =  3.4685198578491603
# epochs =  0 , index =  7800 , loss value =  3.3595139938687044
# epochs =  0 , index =  8000 , loss value =  3.3510203572322124
# epochs =  0 , index =  8200 , loss value =  3.3490342402236664
# epochs =  0 , index =  8400 , loss value =  3.5624619697202617
# epochs =  0 , index =  8600 , loss value =  3.5094875284394393
# epochs =  0 , index =  8800 , loss value =  3.3421588951698546
# epochs =  0 , index =  9000 , loss value =  3.3147459305726095
# epochs =  0 , index =  9200 , loss value =  3.4404338720892826
# epochs =  0 , index =  9400 , loss value =  3.3294846551632005
# epochs =  0 , index =  9600 , loss value =  3.387289301465632
# epochs =  0 , index =  9800 , loss value =  3.5933332622675325
# epochs =  0 , index =  10000 , loss value =  3.334365885084625
# epochs =  0 , index =  10200 , loss value =  3.3224380172716943
# epochs =  0 , index =  10400 , loss value =  3.5626733092683316
# epochs =  0 , index =  10600 , loss value =  3.3836675780517265
# epochs =  0 , index =  10800 , loss value =  3.505019914337745
# epochs =  0 , index =  11000 , loss value =  3.3415001535345263
# epochs =  0 , index =  11200 , loss value =  3.345118492247834
# epochs =  0 , index =  11400 , loss value =  3.3651519278020534
# epochs =  0 , index =  11600 , loss value =  3.457249447591674
# epochs =  0 , index =  11800 , loss value =  3.5240592109279376
# epochs =  0 , index =  12000 , loss value =  3.3504642215663902
# epochs =  0 , index =  12200 , loss value =  3.3430571416415216
# epochs =  0 , index =  12400 , loss value =  3.3861595764303636
# epochs =  0 , index =  12600 , loss value =  3.4078686669062295
# epochs =  0 , index =  12800 , loss value =  3.4917467713930526
# epochs =  0 , index =  13000 , loss value =  3.3500624975270874
# epochs =  0 , index =  13200 , loss value =  3.432936079798986
# epochs =  0 , index =  13400 , loss value =  3.407763095699748
# epochs =  0 , index =  13600 , loss value =  3.416687657226622
# epochs =  0 , index =  13800 , loss value =  3.4824351758757777
# epochs =  0 , index =  14000 , loss value =  3.3197472227058413
# epochs =  0 , index =  14200 , loss value =  3.414881407412193
# epochs =  0 , index =  14400 , loss value =  3.462678248910432
# epochs =  0 , index =  14600 , loss value =  3.274729313652204
# epochs =  0 , index =  14800 , loss value =  3.5078657274340905
# epochs =  0 , index =  15000 , loss value =  3.5108304527448992
# epochs =  0 , index =  15200 , loss value =  3.3788249531594032
# epochs =  0 , index =  15400 , loss value =  3.5209677685562126
# epochs =  0 , index =  15600 , loss value =  3.3697436712513356
# epochs =  0 , index =  15800 , loss value =  3.467230005414084
# epochs =  0 , index =  16000 , loss value =  3.483924849548261
# epochs =  0 , index =  16200 , loss value =  3.360001257217611
# epochs =  0 , index =  16400 , loss value =  3.393181927783052
# epochs =  0 , index =  16600 , loss value =  3.5232435529868456
# epochs =  0 , index =  16800 , loss value =  3.4160562392640865
# epochs =  0 , index =  17000 , loss value =  3.4436208886350324
# epochs =  0 , index =  17200 , loss value =  3.5444925381662293
# epochs =  0 , index =  17400 , loss value =  3.634522098246189
# epochs =  0 , index =  17600 , loss value =  3.5058294498118343
# epochs =  0 , index =  17800 , loss value =  3.392600495080243
# epochs =  0 , index =  18000 , loss value =  3.2821303175970327
# epochs =  0 , index =  18200 , loss value =  3.294294281337657
# epochs =  0 , index =  18400 , loss value =  3.2057752443236325
# epochs =  0 , index =  18600 , loss value =  3.525428010315508
# epochs =  0 , index =  18800 , loss value =  3.2668607065718316
# epochs =  0 , index =  19000 , loss value =  3.458419246095081
# epochs =  0 , index =  19200 , loss value =  3.468903791149698
# epochs =  0 , index =  19400 , loss value =  3.2835789837817435
# epochs =  0 , index =  19600 , loss value =  3.4485644490087863
# epochs =  0 , index =  19800 , loss value =  3.4564578212468775
# epochs =  0 , index =  20000 , loss value =  3.3610273866990186
# epochs =  0 , index =  20200 , loss value =  3.3438638168874606
# epochs =  0 , index =  20400 , loss value =  3.447343070090832
# epochs =  0 , index =  20600 , loss value =  3.3021326075000963
# epochs =  0 , index =  20800 , loss value =  3.3472757059384315
# epochs =  0 , index =  21000 , loss value =  3.4908151755630907
# epochs =  0 , index =  21200 , loss value =  3.2621343805830967
# epochs =  0 , index =  21400 , loss value =  3.4905557498174127
# epochs =  0 , index =  21600 , loss value =  3.404262659356933
# epochs =  0 , index =  21800 , loss value =  3.380206747857543
# epochs =  0 , index =  22000 , loss value =  3.307686701219851
# epochs =  0 , index =  22200 , loss value =  3.2451716392054033
# epochs =  0 , index =  22400 , loss value =  3.479441906420186
# epochs =  0 , index =  22600 , loss value =  3.5035692437689945
# epochs =  0 , index =  22800 , loss value =  3.317777732834169
# epochs =  0 , index =  23000 , loss value =  3.394679225595906
# epochs =  0 , index =  23200 , loss value =  3.532180948502843
# epochs =  0 , index =  23400 , loss value =  3.462587012967529
# epochs =  0 , index =  23600 , loss value =  3.3917939393992995
# epochs =  0 , index =  23800 , loss value =  3.4003352416582664
# epochs =  0 , index =  24000 , loss value =  3.4640807475092563
# epochs =  0 , index =  24200 , loss value =  3.3870012295523297
# epochs =  0 , index =  24400 , loss value =  3.371171396826611
# epochs =  0 , index =  24600 , loss value =  3.466271251970087
# epochs =  0 , index =  24800 , loss value =  3.2854012689218246
# epochs =  0 , index =  25000 , loss value =  3.4153324464848027
# epochs =  0 , index =  25200 , loss value =  3.314860775707938
# epochs =  0 , index =  25400 , loss value =  3.373899260252188
# epochs =  0 , index =  25600 , loss value =  3.2209460327347132
# epochs =  0 , index =  25800 , loss value =  3.156030935060865
# epochs =  0 , index =  26000 , loss value =  3.3172631948441507
# epochs =  0 , index =  26200 , loss value =  3.414928041399028
# epochs =  0 , index =  26400 , loss value =  3.444068536626461
# epochs =  0 , index =  26600 , loss value =  3.4169316367093927
# epochs =  0 , index =  26800 , loss value =  3.423329064118199
# epochs =  0 , index =  27000 , loss value =  3.3937287374109197
# epochs =  0 , index =  27200 , loss value =  3.54347034663424
# epochs =  0 , index =  27400 , loss value =  3.406876246826326
# epochs =  0 , index =  27600 , loss value =  3.367930089107838
# epochs =  0 , index =  27800 , loss value =  3.582036749538478
# epochs =  0 , index =  28000 , loss value =  3.2884439476493372
# epochs =  0 , index =  28200 , loss value =  3.3191990143109353
# epochs =  0 , index =  28400 , loss value =  3.4586006550300388
# epochs =  0 , index =  28600 , loss value =  3.439033625177356
# epochs =  0 , index =  28800 , loss value =  3.487002556340801
# epochs =  0 , index =  29000 , loss value =  3.3722203394647567
# epochs =  0 , index =  29200 , loss value =  3.3777120356782393
# epochs =  0 , index =  29400 , loss value =  3.32952096045548
# epochs =  0 , index =  29600 , loss value =  3.392383088486896
# epochs =  0 , index =  29800 , loss value =  3.5328728212617153
# epochs =  0 , index =  30000 , loss value =  3.5427267356541408
# epochs =  0 , index =  30200 , loss value =  3.251419893573345
# epochs =  0 , index =  30400 , loss value =  3.4137004348367075
# epochs =  0 , index =  30600 , loss value =  3.463564321304225
# epochs =  0 , index =  30800 , loss value =  3.4062852757209363
# epochs =  0 , index =  31000 , loss value =  3.353134910379014
# epochs =  0 , index =  31200 , loss value =  3.2898107714785656
# epochs =  0 , index =  31400 , loss value =  3.242230784160436
# epochs =  0 , index =  31600 , loss value =  3.4670287307224847
# epochs =  0 , index =  31800 , loss value =  3.432065169591472
# epochs =  0 , index =  32000 , loss value =  3.468786033618097
# epochs =  0 , index =  32200 , loss value =  3.458825752567316
# epochs =  0 , index =  32400 , loss value =  3.397549750243504
# epochs =  0 , index =  32600 , loss value =  3.3711253032307873
# epochs =  0 , index =  32800 , loss value =  3.5466993722764544
# epochs =  0 , index =  33000 , loss value =  3.3788415126299354
# epochs =  0 , index =  33200 , loss value =  3.5421269399396644
# epochs =  0 , index =  33400 , loss value =  3.4395742051288427
# epochs =  0 , index =  33600 , loss value =  3.145985047155418
# epochs =  0 , index =  33800 , loss value =  3.1817717261633565
# epochs =  0 , index =  34000 , loss value =  3.347134818660071
# epochs =  0 , index =  34200 , loss value =  3.4061548371138115
# epochs =  0 , index =  34400 , loss value =  3.607661635054837
# epochs =  0 , index =  34600 , loss value =  3.329243939668963
# epochs =  0 , index =  34800 , loss value =  3.696577482900229
# epochs =  0 , index =  35000 , loss value =  3.330588284966529
# epochs =  0 , index =  35200 , loss value =  3.479786239643016
# epochs =  0 , index =  35400 , loss value =  3.5883949219585034
# epochs =  0 , index =  35600 , loss value =  3.2426854450565
# epochs =  0 , index =  35800 , loss value =  3.370053531303192
# epochs =  0 , index =  36000 , loss value =  3.4577210036802093
# epochs =  0 , index =  36200 , loss value =  3.5034815900356167
# epochs =  0 , index =  36400 , loss value =  3.336067998105454
# epochs =  0 , index =  36600 , loss value =  3.5375958581535705
# epochs =  0 , index =  36800 , loss value =  3.441729443533845
# epochs =  0 , index =  37000 , loss value =  3.3807520804403866
# epochs =  0 , index =  37200 , loss value =  3.2908451593719437
# epochs =  0 , index =  37400 , loss value =  3.3179847231787885
# epochs =  0 , index =  37600 , loss value =  3.3821797653035954
# epochs =  0 , index =  37800 , loss value =  3.4144620051405714
# epochs =  0 , index =  38000 , loss value =  3.3907396798620915
# epochs =  0 , index =  38200 , loss value =  3.2974866647109495
# epochs =  0 , index =  38400 , loss value =  3.3415435656825205
# epochs =  0 , index =  38600 , loss value =  3.5991551504292705
# epochs =  0 , index =  38800 , loss value =  3.4055441720548165
# epochs =  0 , index =  39000 , loss value =  3.517106132069098
# epochs =  0 , index =  39200 , loss value =  3.368361681682219
# epochs =  0 , index =  39400 , loss value =  3.59952733414806
# epochs =  0 , index =  39600 , loss value =  3.5055082361733274
# epochs =  0 , index =  39800 , loss value =  3.388194798509517
# epochs =  0 , index =  40000 , loss value =  3.4781858461544672
# epochs =  0 , index =  40200 , loss value =  3.286812292173332
# epochs =  0 , index =  40400 , loss value =  3.1886318758133774
# epochs =  0 , index =  40600 , loss value =  3.4509636726423407
# epochs =  0 , index =  40800 , loss value =  3.4485186269599324
# epochs =  0 , index =  41000 , loss value =  3.513369254455396
# epochs =  0 , index =  41200 , loss value =  3.4123067753460967
# epochs =  0 , index =  41400 , loss value =  3.420955450186093
# epochs =  0 , index =  41600 , loss value =  3.277485779155224
# epochs =  0 , index =  41800 , loss value =  3.2918636877107494
# epochs =  0 , index =  42000 , loss value =  3.1531866269514306
# epochs =  0 , index =  42200 , loss value =  3.344116840749679
# epochs =  0 , index =  42400 , loss value =  3.381998313003243
# epochs =  0 , index =  42600 , loss value =  3.4012598696608314
# epochs =  0 , index =  42800 , loss value =  3.2888259124765
# epochs =  0 , index =  43000 , loss value =  3.3781457300857585
# epochs =  0 , index =  43200 , loss value =  3.3532597624702407
# epochs =  0 , index =  43400 , loss value =  3.267955109791841
# epochs =  0 , index =  43600 , loss value =  3.6042381003634065
# epochs =  0 , index =  43800 , loss value =  3.387377587315531
# epochs =  0 , index =  44000 , loss value =  3.5765354555882016
# epochs =  0 , index =  44200 , loss value =  3.319686958702106
# epochs =  0 , index =  44400 , loss value =  3.3488003423390222
# epochs =  0 , index =  44600 , loss value =  3.3489152032892013
# epochs =  0 , index =  44800 , loss value =  3.3493561041868807
# epochs =  0 , index =  45000 , loss value =  3.5704449986265505
# epochs =  0 , index =  45200 , loss value =  3.2255118867442945
# epochs =  0 , index =  45400 , loss value =  3.440309793711627
# epochs =  0 , index =  45600 , loss value =  3.2870626328663897
# epochs =  0 , index =  45800 , loss value =  3.3941110172498847
# epochs =  0 , index =  46000 , loss value =  3.4548604206758755
# epochs =  0 , index =  46200 , loss value =  3.4805875340287966
# epochs =  0 , index =  46400 , loss value =  3.3491328441727
# epochs =  0 , index =  46600 , loss value =  3.247567484908275
# epochs =  0 , index =  46800 , loss value =  3.4716441200316464
# epochs =  0 , index =  47000 , loss value =  3.3390476184923337
# epochs =  0 , index =  47200 , loss value =  3.3712934386610782
# epochs =  0 , index =  47400 , loss value =  3.2608410547054314
# epochs =  0 , index =  47600 , loss value =  3.3657421314826648
# epochs =  0 , index =  47800 , loss value =  3.4669594246313067
# epochs =  0 , index =  48000 , loss value =  3.5454127978881966
# epochs =  0 , index =  48200 , loss value =  3.4117650123456156
# epochs =  0 , index =  48400 , loss value =  3.518400357713123
# epochs =  0 , index =  48600 , loss value =  3.3290434132879754
# epochs =  0 , index =  48800 , loss value =  3.5785023549872093
# epochs =  0 , index =  49000 , loss value =  3.214964331396402
# epochs =  0 , index =  49200 , loss value =  3.4820064600307483
# epochs =  0 , index =  49400 , loss value =  3.5488496350998795
# epochs =  0 , index =  49600 , loss value =  3.340841100782064
# epochs =  0 , index =  49800 , loss value =  3.3967791544846806
# epochs =  0 , index =  50000 , loss value =  3.2990717243930834
# epochs =  0 , index =  50200 , loss value =  3.401835530322714
# epochs =  0 , index =  50400 , loss value =  3.3475162370262455
# epochs =  0 , index =  50600 , loss value =  3.3298796704688707
# epochs =  0 , index =  50800 , loss value =  3.3939843800253673
# epochs =  0 , index =  51000 , loss value =  3.2912245154938122
# epochs =  0 , index =  51200 , loss value =  3.4411735306766893
# epochs =  0 , index =  51400 , loss value =  3.477316053431024
# epochs =  0 , index =  51600 , loss value =  3.5460491238856333
# epochs =  0 , index =  51800 , loss value =  3.392823690131177
# epochs =  0 , index =  52000 , loss value =  3.4458657412357825
# epochs =  0 , index =  52200 , loss value =  3.5405577865957487
# epochs =  0 , index =  52400 , loss value =  3.476600816930899
# epochs =  0 , index =  52600 , loss value =  3.479026335599219
# epochs =  0 , index =  52800 , loss value =  3.4320068747332275
# epochs =  0 , index =  53000 , loss value =  3.6176200011018618
# epochs =  0 , index =  53200 , loss value =  3.5796909555799714
# epochs =  0 , index =  53400 , loss value =  3.4418871294385083
# epochs =  0 , index =  53600 , loss value =  3.4522499423620916
# epochs =  0 , index =  53800 , loss value =  3.4499629436741213
# epochs =  0 , index =  54000 , loss value =  3.445228533750179
# epochs =  0 , index =  54200 , loss value =  3.5647292270980895
# epochs =  0 , index =  54400 , loss value =  3.498608055302974
# epochs =  0 , index =  54600 , loss value =  3.4746870609677627
# epochs =  0 , index =  54800 , loss value =  3.5133349179264868
# epochs =  0 , index =  55000 , loss value =  3.398857348692279
# epochs =  0 , index =  55200 , loss value =  3.567430052623516
# epochs =  0 , index =  55400 , loss value =  3.390469319834805
# epochs =  0 , index =  55600 , loss value =  3.472263188611203
# epochs =  0 , index =  55800 , loss value =  3.453347485416582
# epochs =  0 , index =  56000 , loss value =  3.4580967537287273
# epochs =  0 , index =  56200 , loss value =  3.428811097561493
# epochs =  0 , index =  56400 , loss value =  3.283371950781103
# epochs =  0 , index =  56600 , loss value =  3.4476489535200945
# epochs =  0 , index =  56800 , loss value =  3.379342117902241
# epochs =  0 , index =  57000 , loss value =  3.4233169658349145
# epochs =  0 , index =  57200 , loss value =  3.3519318597677676
# epochs =  0 , index =  57400 , loss value =  3.323931429074903
# epochs =  0 , index =  57600 , loss value =  3.1414275211651654
# epochs =  0 , index =  57800 , loss value =  3.3323686378458173
# epochs =  0 , index =  58000 , loss value =  3.2608579917316645
# epochs =  0 , index =  58200 , loss value =  3.347709233234707
# epochs =  0 , index =  58400 , loss value =  3.47286837061851
# epochs =  0 , index =  58600 , loss value =  3.2646265543872253
# epochs =  0 , index =  58800 , loss value =  3.3026357090898797
# epochs =  0 , index =  59000 , loss value =  3.471661893195849
# epochs =  0 , index =  59200 , loss value =  3.2759365641213773
# epochs =  0 , index =  59400 , loss value =  3.4698738831286757
# epochs =  0 , index =  59600 , loss value =  3.4334442977668003
# epochs =  0 , index =  59800 , loss value =  3.5153585688658935
#
# Elapsed Time =>  1:16:24.946981

# %%
try:
    
    test_data = np.loadtxt('./mnist_test.csv', delimiter=',', dtype=np.float32)
    print("test_data.shape = ", test_data.shape)

    test_input_data = test_data[ :, 1: ]
    test_target_data = test_data[ :, 0 ]

    (accuracy_ret, false_list) = obj.accuracy(test_input_data, test_target_data) 

    print('Current Accuracy = ', accuracy_ret)
    
except Exception as err:
    
    print('Exception occur !!')
# Out:
# test_data.shape =  (10000, 785)
# Current Accuracy =  0.0958

# %%
# 손실함수 추세 확인
Y_DATA_LIST = []

for index in range(0, len(loss_val_list), 500):
    Y_DATA_LIST.append(loss_val_list[index])
    
plt.title('MNIST Loss Value Trend')
plt.xlabel('data index ( X 500 )')
plt.ylabel('loss value')
plt.grid()
plt.ylim(2.1, 7.1)
plt.plot(Y_DATA_LIST, color='b')
plt.show()

# %%
# 손실함수 추세 확인
Y_DATA_LIST = []

for index in range(0, len(loss_val_list), 200):
    Y_DATA_LIST.append(loss_val_list[index])
    
plt.title('MNIST Loss Value Trend')
plt.xlabel('data index ( X 200 )')
plt.ylabel('loss value')
plt.grid()
plt.ylim(2.1, 7.1)
plt.plot(Y_DATA_LIST, color='b')
plt.show()

# %%
# 손실함수 추세 확인
Y_DATA_LIST = []

for index in range(0, len(loss_val_list), 100):
    Y_DATA_LIST.append(loss_val_list[index])
    
plt.title('MNIST Loss Value Trend')
plt.xlabel('data index ( X 100 )')
plt.ylabel('loss value')
plt.grid()
plt.ylim(2.1, 7.1)
plt.plot(Y_DATA_LIST, color='b')
plt.show()
