# %% [markdown]
# ### [예제 1]  Feed Forward 이해 및 계산 연습

# %%
import numpy as np


# 수치미분 함수
def numerical_derivative(f, x):
    delta_x = 1e-4 # 0.0001
    grad = np.zeros_like(x)
    
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    
    while not it.finished:
        idx = it.multi_index        
        tmp_val = x[idx]
        x[idx] = float(tmp_val) + delta_x
        fx1 = f(x) # f(x+delta_x)
        
        x[idx] = float(tmp_val) - delta_x 
        fx2 = f(x) # f(x-delta_x)
        grad[idx] = (fx1 - fx2) / (2*delta_x)
        
        x[idx] = tmp_val 
        it.iternext()   
        
    return grad

# 활성화함수 sigmoid
def sigmoid(x):
    
    return 1 / (1 + np.exp(-x))

# %%
input_data = np.array([1, 2])    # 입력데이터
target_data = np.array([1])      # 정답데이터

# %% [markdown]
# #### 신경망 아키텍처 그려볼것

# %%
input_nodes = 2    # 입력노드
hidden_nodes = 3   # 은닉노드
output_nodes = 1   # 출력노드

# %% [markdown]
# #### 신경망 아키텍처 그려볼것

# %%
W2 = np.random.rand(input_nodes, hidden_nodes)
b2 = np.random.rand(hidden_nodes)

W3 = np.random.rand(hidden_nodes, output_nodes)
b3 = np.random.rand(output_nodes)

print("W2 = ", W2, ", W2.shape = ", W2.shape)
print("b2 = ", b2, ", b2.shape = ", b2.shape)
print("W3 = ", W3, ", W3.shape = ", W3.shape)
print("b3 = ", b3, ", b3.shape = ", b3.shape)
# Out:
# W2 =  [[0.81428247 0.59692157 0.14495423]
#  [0.09647806 0.56243479 0.39713693]] , W2.shape =  (2, 3)
# b2 =  [0.34253596 0.10342585 0.08102516] , b2.shape =  (3,)
# W3 =  [[0.30584363]
#  [0.13314962]
#  [0.46751947]] , W3.shape =  (3, 1)
# b3 =  [0.90240673] , b3.shape =  (1,)

# %% [markdown]
# #### Z2, A2, Z3, y(=A3), loss 값을 신경망 아키텍처에서 설명해볼것

# %%
def feed_forward(xdata):
    
    delta = 1e-7
    
    Z2 = np.dot(xdata, W2) + b2
    
    print("[feed_forward function]")
    
    print("Z2 = ", Z2)
    
    A2 = sigmoid(Z2)
    
    print("A2 = ", A2)
    
    Z3 = np.dot(A2, W3) + b3
    
    print("Z3 = ", Z3)
    
    y = A3 = sigmoid(Z3)
    
    print("y = ", y, ", A3 = ", A3)
    
    loss = -np.sum( target_data*np.log(y + delta) + (1-target_data)*np.log((1 - y)+delta ) )
    
    print('current loss val = ', loss)
    
    print("[feed_forward function]")
        
    return loss

# %%
loss_val = feed_forward(input_data)
# Out:
# [feed_forward function]
# Z2 =  [1.34977456 1.82521699 1.02025325]
# A2 =  [0.79409277 0.86119095 0.73502193]
# Z3 =  [1.60357924]
# y =  [0.83251804] , A3 =  [0.83251804]
# current loss val =  0.18330026809489158
# [feed_forward function]

# %% [markdown]
# #### 수치미분을 이용하여 가중치 W2, W3, 바이어스 b2, b3 업데이트

# %%
learning_rate = 1e-1

f = lambda x : feed_forward(input_data)
print('\n=================================================')
print('initial W2 = ', W2)
print('initial b2 = ', b2)
print('initial W3 = ', W3)
print('initial b3 = ', b3)
print('=================================================\n')

W2 -= learning_rate * numerical_derivative( f, W2 )
b2 -= learning_rate * numerical_derivative( f, b2 )

W3 -= learning_rate * numerical_derivative( f, W3 )
b3 -= learning_rate * numerical_derivative( f, b3 )

print('\n=================================================')
print('updated W2 = ', W2)
print('updated b2 = ', b2)
print('updated W3 = ', W3)
print('updated b3 = ', b3)
print('=================================================\n')
# Out:
# =================================================
# initial W2 =  [[0.81428247 0.59692157 0.14495423]
#  [0.09647806 0.56243479 0.39713693]]
# initial b2 =  [0.34253596 0.10342585 0.08102516]
# initial W3 =  [[0.30584363]
#  [0.13314962]
#  [0.46751947]]
# initial b3 =  [0.90240673]
# =================================================
#
# [feed_forward function]
# Z2 =  [1.34987456 1.82521699 1.02025325]
# A2 =  [0.79410912 0.86119095 0.73502193]
# Z3 =  [1.60358424]
# y =  [0.83251874] , A3 =  [0.83251874]
# current loss val =  0.18329943057220416
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.34967456 1.82521699 1.02025325]
# A2 =  [0.79407642 0.86119095 0.73502193]
# Z3 =  [1.60357424]
# y =  [0.83251734] , A3 =  [0.83251734]
# current loss val =  0.1833011056703293
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.34977456 1.82531699 1.02025325]
# A2 =  [0.79409277 0.8612029  0.73502193]
# Z3 =  [1.60358084]
# y =  [0.83251826] , A3 =  [0.83251826]
# current loss val =  0.1833000015261795
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.34977456 1.82511699 1.02025325]
# A2 =  [0.79409277 0.86117899 0.73502193]
# Z3 =  [1.60357765]
# y =  [0.83251782] , A3 =  [0.83251782]
# current loss val =  0.1833005346832141
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.34977456 1.82521699 1.02035325]
# A2 =  [0.79409277 0.86119095 0.7350414 ]
# Z3 =  [1.60358835]
# y =  [0.83251931] , A3 =  [0.83251931]
# current loss val =  0.1832987431081661
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.34977456 1.82521699 1.02015325]
# A2 =  [0.79409277 0.86119095 0.73500245]
# Z3 =  [1.60357014]
# y =  [0.83251677] , A3 =  [0.83251677]
# current loss val =  0.18330179316486075
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.34997456 1.82521699 1.02025325]
# A2 =  [0.79412547 0.86119095 0.73502193]
# Z3 =  [1.60358925]
# y =  [0.83251943] , A3 =  [0.83251943]
# current loss val =  0.18329859310226645
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.34957456 1.82521699 1.02025325]
# A2 =  [0.79406007 0.86119095 0.73502193]
# Z3 =  [1.60356924]
# y =  [0.83251664] , A3 =  [0.83251664]
# current loss val =  0.18330194329851823
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.34977456 1.82541699 1.02025325]
# A2 =  [0.79409277 0.86121485 0.73502193]
# Z3 =  [1.60358243]
# y =  [0.83251848] , A3 =  [0.83251848]
# current loss val =  0.18329973497707688
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.34977456 1.82501699 1.02025325]
# A2 =  [0.79409277 0.86116704 0.73502193]
# Z3 =  [1.60357606]
# y =  [0.8325176] , A3 =  [0.8325176]
# current loss val =  0.18330080129114773
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.34977456 1.82521699 1.02045325]
# A2 =  [0.79409277 0.86119095 0.73506088]
# Z3 =  [1.60359745]
# y =  [0.83252058] , A3 =  [0.83252058]
# current loss val =  0.18329721820468495
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.34977456 1.82521699 1.02005325]
# A2 =  [0.79409277 0.86119095 0.73498297]
# Z3 =  [1.60356103]
# y =  [0.8325155] , A3 =  [0.8325155]
# current loss val =  0.18330331831807278
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35406231 1.82654988 1.02787839]
# A2 =  [0.79479297 0.86135021 0.73650437]
# Z3 =  [1.60450767]
# y =  [0.83264745] , A3 =  [0.83264745]
# current loss val =  0.18314483300145634
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35386231 1.82654988 1.02787839]
# A2 =  [0.79476035 0.86135021 0.73650437]
# Z3 =  [1.6044977]
# y =  [0.83264606] , A3 =  [0.83264606]
# current loss val =  0.18314650268959967
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35396231 1.82664988 1.02787839]
# A2 =  [0.79477666 0.86136215 0.73650437]
# Z3 =  [1.60450428]
# y =  [0.83264698] , A3 =  [0.83264698]
# current loss val =  0.1831454017117504
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35396231 1.82644988 1.02787839]
# A2 =  [0.79477666 0.86133826 0.73650437]
# Z3 =  [1.6045011]
# y =  [0.83264654] , A3 =  [0.83264654]
# current loss val =  0.1831459339462039
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35396231 1.82654988 1.02797839]
# A2 =  [0.79477666 0.86135021 0.73652378]
# Z3 =  [1.60451176]
# y =  [0.83264802] , A3 =  [0.83264802]
# current loss val =  0.1831441494736657
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35396231 1.82654988 1.02777839]
# A2 =  [0.79477666 0.86135021 0.73648496]
# Z3 =  [1.60449361]
# y =  [0.83264549] , A3 =  [0.83264549]
# current loss val =  0.18314718624799584
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35479715 1.826816   1.02939678]
# A2 =  [0.7949128  0.86138198 0.73679893]
# Z3 =  [1.60476576]
# y =  [0.83268341] , A3 =  [0.83268341]
# current loss val =  0.1831016467569282
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35479715 1.826816   1.02939678]
# A2 =  [0.7949128  0.86138198 0.73679893]
# Z3 =  [1.60460677]
# y =  [0.83266126] , A3 =  [0.83266126]
# current loss val =  0.18312824893391305
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35479715 1.826816   1.02939678]
# A2 =  [0.7949128  0.86138198 0.73679893]
# Z3 =  [1.6047724]
# y =  [0.83268434] , A3 =  [0.83268434]
# current loss val =  0.18310053462036527
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35479715 1.826816   1.02939678]
# A2 =  [0.7949128  0.86138198 0.73679893]
# Z3 =  [1.60460013]
# y =  [0.83266033] , A3 =  [0.83266033]
# current loss val =  0.18312936122386697
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35479715 1.826816   1.02939678]
# A2 =  [0.7949128  0.86138198 0.73679893]
# Z3 =  [1.60475995]
# y =  [0.8326826] , A3 =  [0.8326826]
# current loss val =  0.18310261910052117
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35479715 1.826816   1.02939678]
# A2 =  [0.7949128  0.86138198 0.73679893]
# Z3 =  [1.60461259]
# y =  [0.83266207] , A3 =  [0.83266207]
# current loss val =  0.183127276466298
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35479715 1.826816   1.02939678]
# A2 =  [0.7949128  0.86138198 0.73679893]
# Z3 =  [1.63685859]
# y =  [0.83710703] , A3 =  [0.83710703]
# current loss val =  0.17780322162024909
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.35479715 1.826816   1.02939678]
# A2 =  [0.7949128  0.86138198 0.73679893]
# Z3 =  [1.63665859]
# y =  [0.83707976] , A3 =  [0.83707976]
# current loss val =  0.17783580293728282
# [feed_forward function]
#
# =================================================
# updated W2 =  [[0.81512002 0.59718815 0.14647925]
#  [0.09815316 0.56296794 0.40018699]]
# updated b2 =  [0.3433708  0.10369197 0.08254355]
# updated W3 =  [[0.31914471]
#  [0.14756292]
#  [0.47984815]]
# updated b3 =  [0.91869739]
# =================================================
